# %%
# !python -V
# Out:
# Python 3.9.13

# %%
# data manipulation and storage
import pandas as pd

# plotting and graphs
import seaborn as sns
import matplotlib.pyplot as plt

# data preprocessing
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import StandardScaler

# models
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
import xgboost as xgb

# model performance metrics
from sklearn.metrics import mean_squared_error

# saving model to file
import pickle

# mlflow for experiment tracking
import mlflow
mlflow.set_tracking_uri('sqlite:///mlflow.db')
mlflow.set_experiment('nyc-taxi-duration-experiment')

# hyper-parameter optimization
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
df_train = pd.read_parquet('./data/train_data.parquet')
df_val = pd.read_parquet('./data/validation_data.parquet')

# %%
categorical = ['PU_DO_pair']
# ['PULocationID','DOLocationID']
numerical = ['trip_distance','fare_amount']
target = 'duration'
# Pre Processing - Numerical
scaler = StandardScaler()
df_train[numerical] = scaler.fit_transform(df_train[numerical])
df_val[numerical] = scaler.transform(df_val[numerical])
train_dicts = df_train[categorical+numerical].to_dict(orient='records')
val_dicts = df_val[categorical+numerical].to_dict(orient='records')
# Pre Processing - Categorical
df_train[categorical] = df_train[categorical].astype(str)
df_val[categorical] = df_val[categorical].astype(str)
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)
y_train = df_train[target].values
X_val = dv.transform(val_dicts)
y_val = df_val[target].values

# %%
# Track single trial in an MLFlow epxeriment
with mlflow.start_run():

    mlflow.set_tag('developer','sam')

    mlflow.log_param('train-data-path','./data/green_tripdata_2021-01.parquet')
    mlflow.log_param('val-data-path','./data/green_tripdata_2021-02.parquet')

    alpha = 10
    mlflow.log_param('alpha',alpha)
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_train,y_train)
    y_pred_lasso = lasso_model.predict(X_val)
    rmse = mean_squared_error(y_val,y_pred_lasso,squared=False)
    mlflow.log_metric('rmse',rmse)

# %%
train = xgb.DMatrix(X_train,label=y_train)
valid = xgb.DMatrix(X_val, label = y_val)

# %%
# define objective function
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag('model','xgboost')
        mlflow.log_params(params)
        xgb_model = xgb.train(
            params = params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid,'validation')],
            early_stopping_rounds=50
        )
        y_pred = xgb_model.predict(valid)
        rmse = mean_squared_error(y_val,y_pred,squared=False)
        mlflow.log_metric('rmse',rmse)

    return {'loss':rmse,'status':STATUS_OK}

# define hyper-parameter search space
search_space = {
    'max_depth':scope.int(hp.quniform('max_depth',4,100,1)),
    'learning_rate':hp.loguniform('learning_rate',-3,0),
    'reg_alpha':hp.loguniform('reg_alpha',-5,-1),
    'reg_lambda':hp.loguniform('reg_lambda',-6,-1),
    'min_child_weight':hp.loguniform('min_child_weight',-1,3),
    'objective':'reg:linear',
    'seed':42
}

# Perform 50 Trials
best_result = fmin(
    fn = objective,
    space = search_space,
    algo = tpe.suggest,
    max_evals=50,
    trials = Trials()
)

# %%
# Perform single trial
# with Auto Logging for MLFlow enabled

params = {
    'learning_rate'	:0.3684464953620537,
    'max_depth':	26,
    'min_child_weight':1.7718990147468716,
    'objective':	'reg:linear',
    'reg_alpha':	0.007003237008779855,
    'reg_lambda':	0.2740301294083138,
    'seed':	42
}

mlflow.xgboost.autolog()

xgb.train(
    params = params,
    dtrain = train,
    num_boost_round = 1000,
    evals = [(valid,'validation')],
    early_stopping_rounds = 50
)
# Out:
# 2022/10/19 15:05:56 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '286cb97a58414adbad76946c4e7f65cf', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [15:05:56] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.35528
# [1]	validation-rmse:11.10603
# [2]	validation-rmse:8.68452
# [3]	validation-rmse:7.34160
# [4]	validation-rmse:6.64989
# [5]	validation-rmse:6.28914
# [6]	validation-rmse:6.08637
# [7]	validation-rmse:5.97482
# [8]	validation-rmse:5.91450
# [9]	validation-rmse:5.86644
# [10]	validation-rmse:5.84206
# [11]	validation-rmse:5.82689
# [12]	validation-rmse:5.81749
# [13]	validation-rmse:5.81223
# [14]	validation-rmse:5.80828
# [15]	validation-rmse:5.80637
# [16]	validation-rmse:5.80343
# [17]	validation-rmse:5.80197
# [18]	validation-rmse:5.80099
# [19]	validation-rmse:5.79935
# [20]	validation-rmse:5.79831
# [21]	validation-rmse:5.79668
# [22]	validation-rmse:5.79601
# [23]	validation-rmse:5.79501
# [24]	validation-rmse:5.79419
# [25]	validation-rmse:5.79260
# [26]	validation-rmse:5.79219
# [27]	validation-rmse:5.79167
# [28]	validation-rmse:5.78964
# [29]	validation-rmse:5.78871
# [30]	validation-rmse:5.78780
# [31]	validation-rmse:5.78740
# [32]	validation-rmse:5.78618
# [33]	validation-rmse:5.78529
# [34]	validation-rmse:5.78490
# [35]	validation-rmse:5.78371
# [36]	validation-rmse:5.78240
# [37]	validation-rmse:5.78152
# [38]	validation-rmse:5.78160
# [39]	validation-rmse:5.78030
# [40]	validation-rmse:5.77963
# [41]	validation-rmse:5.77891
# [42]	validation-rmse:5.77871
# [43]	validation-rmse:5.77714
# [44]	validation-rmse:5.77645
# [45]	validation-rmse:5.77547
# [46]	validation-rmse:5.77480
# [47]	validation-rmse:5.77461
# [48]	validation-rmse:5.77444
# [49]	validation-rmse:5.77444
# [50]	validation-rmse:5.77397
# [51]	validation-rmse:5.77404
# [52]	validation-rmse:5.77304
# [53]	validation-rmse:5.77225
# [54]	validation-rmse:5.77158
# [55]	validation-rmse:5.77082
# [56]	validation-rmse:5.77051
# [57]	validation-rmse:5.77002
# [58]	validation-rmse:5.76984
# [59]	validation-rmse:5.76985
# [60]	validation-rmse:5.76961
# [61]	validation-rmse:5.76892
# [62]	validation-rmse:5.76889
# [63]	validation-rmse:5.76864
# [64]	validation-rmse:5.76773
# [65]	validation-rmse:5.76700
# [66]	validation-rmse:5.76641
# [67]	validation-rmse:5.76652
# [68]	validation-rmse:5.76575
# [69]	validation-rmse:5.76529
# [70]	validation-rmse:5.76486
# [71]	validation-rmse:5.76402
# [72]	validation-rmse:5.76374
# [73]	validation-rmse:5.76341
# [74]	validation-rmse:5.76300
# [75]	validation-rmse:5.76256
# [76]	validation-rmse:5.76158
# [77]	validation-rmse:5.76092
# [78]	validation-rmse:5.76043
# [79]	validation-rmse:5.76029
# [80]	validation-rmse:5.76015
# [81]	validation-rmse:5.75916
# [82]	validation-rmse:5.75858
# [83]	validation-rmse:5.75798
# [84]	validation-rmse:5.75789
# [85]	validation-rmse:5.75717
# [86]	validation-rmse:5.75622
# [87]	validation-rmse:5.75603
# [88]	validation-rmse:5.75497
# [89]	validation-rmse:5.75511
# [90]	validation-rmse:5.75521
# [91]	validation-rmse:5.75456
# [92]	validation-rmse:5.75425
# [93]	validation-rmse:5.75380
# [94]	validation-rmse:5.75358
# [95]	validation-rmse:5.75299
# [96]	validation-rmse:5.75308
# [97]	validation-rmse:5.75267
# [98]	validation-rmse:5.75213
# [99]	validation-rmse:5.75181
# [100]	validation-rmse:5.75101
# [101]	validation-rmse:5.75046
# [102]	validation-rmse:5.74933
# [103]	validation-rmse:5.74913
# [104]	validation-rmse:5.74906
# [105]	validation-rmse:5.74902
# [106]	validation-rmse:5.74811
# [107]	validation-rmse:5.74775
# [108]	validation-rmse:5.74709
# [109]	validation-rmse:5.74718
# [110]	validation-rmse:5.74680
# [111]	validation-rmse:5.74658
# [112]	validation-rmse:5.74617
# [113]	validation-rmse:5.74617
# [114]	validation-rmse:5.74590
# [115]	validation-rmse:5.74565
# [116]	validation-rmse:5.74523
# [117]	validation-rmse:5.74535
# [118]	validation-rmse:5.74493
# [119]	validation-rmse:5.74660
# [120]	validation-rmse:5.74582
# [121]	validation-rmse:5.74545
# [122]	validation-rmse:5.74485
# [123]	validation-rmse:5.74456
# [124]	validation-rmse:5.74411
# [125]	validation-rmse:5.74386
# [126]	validation-rmse:5.74362
# [127]	validation-rmse:5.74401
# [128]	validation-rmse:5.74397
# [129]	validation-rmse:5.74416
# [130]	validation-rmse:5.74363
# [131]	validation-rmse:5.74341
# [132]	validation-rmse:5.74334
# [133]	validation-rmse:5.74303
# [134]	validation-rmse:5.74309
# [135]	validation-rmse:5.74225
# [136]	validation-rmse:5.74215
# [137]	validation-rmse:5.74182
# [138]	validation-rmse:5.74150
# [139]	validation-rmse:5.74142
# [140]	validation-rmse:5.74124
# [141]	validation-rmse:5.74119
# [142]	validation-rmse:5.74119
# [143]	validation-rmse:5.74090
# [144]	validation-rmse:5.74096
# [145]	validation-rmse:5.74124
# [146]	validation-rmse:5.74104
# [147]	validation-rmse:5.74086
# [148]	validation-rmse:5.74074
# [149]	validation-rmse:5.74073
# [150]	validation-rmse:5.74069
# [151]	validation-rmse:5.74041
# [152]	validation-rmse:5.74021
# [153]	validation-rmse:5.73997
# [154]	validation-rmse:5.73982
# [155]	validation-rmse:5.73959
# [156]	validation-rmse:5.73954
# [157]	validation-rmse:5.73918
# [158]	validation-rmse:5.73906
# [159]	validation-rmse:5.73881
# [160]	validation-rmse:5.73827
# [161]	validation-rmse:5.73786
# [162]	validation-rmse:5.73747
# [163]	validation-rmse:5.73751
# [164]	validation-rmse:5.73751
# [165]	validation-rmse:5.73802
# [166]	validation-rmse:5.73812
# [167]	validation-rmse:5.73803
# [168]	validation-rmse:5.74317
# [169]	validation-rmse:5.74287
# [170]	validation-rmse:5.74294
# [171]	validation-rmse:5.74265
# [172]	validation-rmse:5.74205
# [173]	validation-rmse:5.74212
# [174]	validation-rmse:5.74219
# [175]	validation-rmse:5.74188
# [176]	validation-rmse:5.74179
# [177]	validation-rmse:5.74149
# [178]	validation-rmse:5.74122
# [179]	validation-rmse:5.74125
# [180]	validation-rmse:5.74081
# [181]	validation-rmse:5.74031
# [182]	validation-rmse:5.74050
# [183]	validation-rmse:5.74017
# [184]	validation-rmse:5.73984
# [185]	validation-rmse:5.73966
# [186]	validation-rmse:5.73947
# [187]	validation-rmse:5.73926
# [188]	validation-rmse:5.73895
# [189]	validation-rmse:5.73842
# [190]	validation-rmse:5.73835
# [191]	validation-rmse:5.73830
# [192]	validation-rmse:5.73826
# [193]	validation-rmse:5.73991
# [194]	validation-rmse:5.73950
# [195]	validation-rmse:5.73971
# [196]	validation-rmse:5.73956
# [197]	validation-rmse:5.73905
# [198]	validation-rmse:5.73899
# [199]	validation-rmse:5.73862
# [200]	validation-rmse:5.73856
# [201]	validation-rmse:5.73822
# [202]	validation-rmse:5.73706
# [203]	validation-rmse:5.73469
# [204]	validation-rmse:5.73451
# [205]	validation-rmse:5.73432
# [206]	validation-rmse:5.72737
# [207]	validation-rmse:5.72711
# [208]	validation-rmse:5.72649
# [209]	validation-rmse:5.72621
# [210]	validation-rmse:5.72633
# [211]	validation-rmse:5.72604
# [212]	validation-rmse:5.72585
# [213]	validation-rmse:5.72546
# [214]	validation-rmse:5.72514
# [215]	validation-rmse:5.72510
# [216]	validation-rmse:5.72506
# [217]	validation-rmse:5.72487
# [218]	validation-rmse:5.72635
# [219]	validation-rmse:5.72640
# [220]	validation-rmse:5.72669
# [221]	validation-rmse:5.72672
# [222]	validation-rmse:5.72673
# [223]	validation-rmse:5.72685
# [224]	validation-rmse:5.72678
# [225]	validation-rmse:5.72660
# [226]	validation-rmse:5.72674
# [227]	validation-rmse:5.72663
# [228]	validation-rmse:5.72641
# [229]	validation-rmse:5.72643
# [230]	validation-rmse:5.72625
# [231]	validation-rmse:5.72606
# [232]	validation-rmse:5.72571
# [233]	validation-rmse:5.72574
# [234]	validation-rmse:5.72589
# [235]	validation-rmse:5.72568
# [236]	validation-rmse:5.72511
# [237]	validation-rmse:5.72466
# [238]	validation-rmse:5.72436
# [239]	validation-rmse:5.72428
# [240]	validation-rmse:5.72417
# [241]	validation-rmse:5.72429
# [242]	validation-rmse:5.72420
# [243]	validation-rmse:5.72435
# [244]	validation-rmse:5.72478
# [245]	validation-rmse:5.72467
# [246]	validation-rmse:5.72437
# [247]	validation-rmse:5.72410
# [248]	validation-rmse:5.72419
# [249]	validation-rmse:5.72427
# [250]	validation-rmse:5.72450
# [251]	validation-rmse:5.72436
# [252]	validation-rmse:5.72368
# [253]	validation-rmse:5.72380
# [254]	validation-rmse:5.72375
# [255]	validation-rmse:5.72368
# [256]	validation-rmse:5.72372
# [257]	validation-rmse:5.72368
# [258]	validation-rmse:5.72362
# [259]	validation-rmse:5.72314
# [260]	validation-rmse:5.72316
# [261]	validation-rmse:5.72320
# [262]	validation-rmse:5.72301
# [263]	validation-rmse:5.72282
# [264]	validation-rmse:5.72285
# [265]	validation-rmse:5.72228
# [266]	validation-rmse:5.72495
# [267]	validation-rmse:5.72518
# [268]	validation-rmse:5.72528
# [269]	validation-rmse:5.72523
# [270]	validation-rmse:5.72503
# [271]	validation-rmse:5.72532
# [272]	validation-rmse:5.72538
# [273]	validation-rmse:5.72520
# [274]	validation-rmse:5.72525
# [275]	validation-rmse:5.72516
# [276]	validation-rmse:5.72508
# [277]	validation-rmse:5.72514
# [278]	validation-rmse:5.72502
# [279]	validation-rmse:5.72486
# [280]	validation-rmse:5.72476
# [281]	validation-rmse:5.72489
# [282]	validation-rmse:5.72486
# [283]	validation-rmse:5.72486
# [284]	validation-rmse:5.72479
# [285]	validation-rmse:5.72466
# [286]	validation-rmse:5.72421
# [287]	validation-rmse:5.72415
# [288]	validation-rmse:5.72614
# [289]	validation-rmse:5.72619
# [290]	validation-rmse:5.72600
# [291]	validation-rmse:5.72635
# [292]	validation-rmse:5.72580
# [293]	validation-rmse:5.72572
# [294]	validation-rmse:5.72570
# [295]	validation-rmse:5.72559
# [296]	validation-rmse:5.72557
# [297]	validation-rmse:5.72539
# [298]	validation-rmse:5.72540
# [299]	validation-rmse:5.72696
# [300]	validation-rmse:5.72715
# [301]	validation-rmse:5.72711
# [302]	validation-rmse:5.72685
# [303]	validation-rmse:5.72690
# [304]	validation-rmse:5.72695
# [305]	validation-rmse:5.72688
# [306]	validation-rmse:5.72677
# [307]	validation-rmse:5.72681
# [308]	validation-rmse:5.72667
# [309]	validation-rmse:5.72677
# [310]	validation-rmse:5.72668
# [311]	validation-rmse:5.72648
# [312]	validation-rmse:5.72739
# [313]	validation-rmse:5.72770
# [314]	validation-rmse:5.72784
# [315]	validation-rmse:5.72784
# 2022/10/19 15:06:27 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2022/10/19 15:06:29 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/mlops/anaconda3/envs/mlops_bootcamp_env/lib/python3.9/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
