# %%
# !python -V
# Out:
# Python 3.9.13

# %%
# data manipulation and storage
import pandas as pd

# plotting and graphs
import seaborn as sns
import matplotlib.pyplot as plt

# data preprocessing
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import StandardScaler

# models
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
import xgboost as xgb

# model performance metrics
from sklearn.metrics import mean_squared_error

# saving model to file
import pickle

# mlflow for experiment tracking
import mlflow
mlflow.set_tracking_uri('sqlite:///mlflow.db')
mlflow.set_experiment('nyc-taxi-duration-experiment')

# hyper-parameter optimization
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
df_train = pd.read_parquet('./data/train_data.parquet')
df_val = pd.read_parquet('./data/validation_data.parquet')

# %%
categorical = ['PU_DO_pair']
# ['PULocationID','DOLocationID']
numerical = ['trip_distance','fare_amount']
target = 'duration'
# Pre Processing - Numerical
scaler = StandardScaler()
df_train[numerical] = scaler.fit_transform(df_train[numerical])
df_val[numerical] = scaler.transform(df_val[numerical])
train_dicts = df_train[categorical+numerical].to_dict(orient='records')
val_dicts = df_val[categorical+numerical].to_dict(orient='records')
# Pre Processing - Categorical
df_train[categorical] = df_train[categorical].astype(str)
df_val[categorical] = df_val[categorical].astype(str)
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)
y_train = df_train[target].values
X_val = dv.transform(val_dicts)
y_val = df_val[target].values

# %%
train = xgb.DMatrix(X_train,label=y_train)
valid = xgb.DMatrix(X_val, label = y_val)

# %%
# define objective function
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag('model','xgboost')
        mlflow.log_params(params)
        xgb_model = xgb.train(
            params = params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid,'validation')],
            early_stopping_rounds=50
        )
        y_pred = xgb_model.predict(valid)
        rmse = mean_squared_error(y_val,y_pred,squared=False)
        mlflow.log_metric('rmse',rmse)

    return {'loss':rmse,'status':STATUS_OK}

# define hyper-parameter search space
search_space = {
    'max_depth':scope.int(hp.quniform('max_depth',4,100,1)),
    'learning_rate':hp.loguniform('learning_rate',-3,0),
    'reg_alpha':hp.loguniform('reg_alpha',-5,-1),
    'reg_lambda':hp.loguniform('reg_lambda',-6,-1),
    'min_child_weight':hp.loguniform('min_child_weight',-1,3),
    'objective':'reg:linear',
    'seed':42
}

# Perform hyper-parameter optimization
best_result = fmin(
    fn = objective,
    space = search_space,
    algo = tpe.suggest,
    max_evals=50,
    trials = Trials()
)
# Out:
# [09:12:17] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:14.64786
# [1]	validation-rmse:10.27208
# [2]	validation-rmse:7.97441
# [3]	validation-rmse:6.85351
# [4]	validation-rmse:6.29722
# [5]	validation-rmse:6.04535
# [6]	validation-rmse:5.91314
# [7]	validation-rmse:5.84456
# [8]	validation-rmse:5.80933
# [9]	validation-rmse:5.78830
# [10]	validation-rmse:5.77625
# [11]	validation-rmse:5.76456
# [12]	validation-rmse:5.76037
# [13]	validation-rmse:5.75917
# [14]	validation-rmse:5.75700
# [15]	validation-rmse:5.75587
# [16]	validation-rmse:5.75390
# [17]	validation-rmse:5.75366
# [18]	validation-rmse:5.75342
# [19]	validation-rmse:5.75264
# [20]	validation-rmse:5.75137
# [21]	validation-rmse:5.75136
# [22]	validation-rmse:5.74995
# [23]	validation-rmse:5.74973
# [24]	validation-rmse:5.74944
# [25]	validation-rmse:5.74886
# [26]	validation-rmse:5.74847
# [27]	validation-rmse:5.74848
# [28]	validation-rmse:5.74819
# [29]	validation-rmse:5.74763
#   0%|          | 0/50 [00:10<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [7], line 31
#      20 search_space = {
#      21     'max_depth':scope.int(hp.quniform('max_depth',4,100,1)),
#      22     'learning_rate':hp.loguniform('learning_rate',-3,0),
#    (...)
#      27     'seed':42
#      28 }
#      30 # Perform 50 Trials
# ---> 31 best_result = fmin(
#      32     fn = objective,
#      33     space = search_space,
#      34     algo = tpe.suggest,
#      35     max_evals=50,
#      36     trials = Trials()
#      37 )
#
# File ~/anaconda3/envs/mlops_bootcamp_env/lib/python3.9/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/anaconda3/envs/mlops_bootcamp_env/lib/python3.9/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/anaconda3/envs/mlops_bootcamp_env/lib/python3.9/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/anaconda3/envs/mlops_bootcamp_env/lib/python3.9/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/anaconda3/envs/mlops_bootcamp_env/lib/python3.9/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/anaconda3/envs/mlops_bootcamp_env/lib/python3.9/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/anaconda3/envs/mlops_bootcamp_env/lib/python3.9/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In [7], line 6, in objective(params)
#       4 mlflow.set_tag('model','xgboost')
#       5 mlflow.log_params(params)
# ----> 6 xgb_model = xgb.train(
#       7     params = params,
#       8     dtrain=train,
#       9     num_boost_round=1000,
#      10     evals=[(valid,'validation')],
#      11     early_stopping_rounds=50
#      12 )
#      13 y_pred = xgb_model.predict(valid)
#      14 rmse = mean_squared_error(y_val,y_pred,squared=False)
#
# File ~/anaconda3/envs/mlops_bootcamp_env/lib/python3.9/site-packages/xgboost/core.py:575, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     573 for k, arg in zip(sig.parameters, args):
#     574     kwargs[k] = arg
# --> 575 return f(**kwargs)
#
# File ~/anaconda3/envs/mlops_bootcamp_env/lib/python3.9/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~/anaconda3/envs/mlops_bootcamp_env/lib/python3.9/site-packages/xgboost/core.py:1778, in Booster.update(self, dtrain, iteration, fobj)
#    1775 self._validate_features(dtrain)
#    1777 if fobj is None:
# -> 1778     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1779                                             ctypes.c_int(iteration),
#    1780                                             dtrain.handle))
#    1781 else:
#    1782     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
# Perform single trial
# with Auto Logging for MLFlow enabled

with mlflow.start_run():

    train = xgb.DMatrix(X_train,label=y_train)
    valid = xgb.DMatrix(X_val,label=y_val)

    params = {
        'learning_rate'	:0.09675711924293533,
        'max_depth':	31,
        'min_child_weight':0.41292138902768033,
        'objective':	'reg:linear',
        'reg_alpha':	0.34559561068374306,
        'reg_lambda':	0.01739291741989833,
        'seed':	42
    }

    mlflow.log_params(params)
    mlflow.xgboost.autolog(disable=True)

    booster = xgb.train(
        params = params,
        dtrain = train,
        num_boost_round = 1000,
        evals = [(valid,'validation')],
        early_stopping_rounds = 50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val,y_pred,squared=False)
    mlflow.log_metric('rmse',rmse)

    with open('models/vectorizer.b','wb') as f_out:
        pickle.dump(dv,f_out)
    
    with open('models/scaler.b','wb') as f_out:
        pickle.dump(scaler,f_out)

    mlflow.log_artifact('models/vectorizer.b',artifact_path="preprocessor")
    mlflow.log_artifact('models/scaler.b',artifact_path="preprocessor")
    mlflow.xgboost.log_model(booster,artifact_path="models_mlflow")
# Out:
# [07:43:50] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:20.59416
# [1]	validation-rmse:18.89255
# [2]	validation-rmse:17.36444
# [3]	validation-rmse:15.99935
# [4]	validation-rmse:14.78185
# [5]	validation-rmse:13.69304
# [6]	validation-rmse:12.72729
# [7]	validation-rmse:11.86636
# [8]	validation-rmse:11.10763
# [9]	validation-rmse:10.43255
# [10]	validation-rmse:9.83785
# [11]	validation-rmse:9.31981
# [12]	validation-rmse:8.85881
# [13]	validation-rmse:8.45440
# [14]	validation-rmse:8.10439
# [15]	validation-rmse:7.79829
# [16]	validation-rmse:7.53456
# [17]	validation-rmse:7.30543
# [18]	validation-rmse:7.10715
# [19]	validation-rmse:6.93526
# [20]	validation-rmse:6.78723
# [21]	validation-rmse:6.65716
# [22]	validation-rmse:6.54524
# [23]	validation-rmse:6.44711
# [24]	validation-rmse:6.36037
# [25]	validation-rmse:6.28807
# [26]	validation-rmse:6.22514
# [27]	validation-rmse:6.17297
# [28]	validation-rmse:6.12676
# [29]	validation-rmse:6.08537
# [30]	validation-rmse:6.05075
# [31]	validation-rmse:6.01976
# [32]	validation-rmse:5.99249
# [33]	validation-rmse:5.96867
# [34]	validation-rmse:5.94590
# [35]	validation-rmse:5.92632
# [36]	validation-rmse:5.90868
# [37]	validation-rmse:5.89288
# [38]	validation-rmse:5.87631
# [39]	validation-rmse:5.86560
# [40]	validation-rmse:5.85479
# [41]	validation-rmse:5.84483
# [42]	validation-rmse:5.83629
# [43]	validation-rmse:5.82817
# [44]	validation-rmse:5.81971
# [45]	validation-rmse:5.80919
# [46]	validation-rmse:5.80179
# [47]	validation-rmse:5.79464
# [48]	validation-rmse:5.78964
# [49]	validation-rmse:5.78434
# [50]	validation-rmse:5.78039
# [51]	validation-rmse:5.77588
# [52]	validation-rmse:5.77316
# [53]	validation-rmse:5.77007
# [54]	validation-rmse:5.76806
# [55]	validation-rmse:5.76626
# [56]	validation-rmse:5.76373
# [57]	validation-rmse:5.76103
# [58]	validation-rmse:5.75993
# [59]	validation-rmse:5.75713
# [60]	validation-rmse:5.75580
# [61]	validation-rmse:5.75488
# [62]	validation-rmse:5.75386
# [63]	validation-rmse:5.75339
# [64]	validation-rmse:5.75269
# [65]	validation-rmse:5.75203
# [66]	validation-rmse:5.75134
# [67]	validation-rmse:5.75082
# [68]	validation-rmse:5.74978
# [69]	validation-rmse:5.74926
# [70]	validation-rmse:5.74891
# [71]	validation-rmse:5.74847
# [72]	validation-rmse:5.74807
# [73]	validation-rmse:5.74778
# [74]	validation-rmse:5.74669
# [75]	validation-rmse:5.74638
# [76]	validation-rmse:5.74619
# [77]	validation-rmse:5.74591
# [78]	validation-rmse:5.74567
# [79]	validation-rmse:5.74542
# [80]	validation-rmse:5.74527
# [81]	validation-rmse:5.74505
# [82]	validation-rmse:5.74472
# [83]	validation-rmse:5.74446
# [84]	validation-rmse:5.74432
# [85]	validation-rmse:5.74419
# [86]	validation-rmse:5.74399
# [87]	validation-rmse:5.74383
# [88]	validation-rmse:5.74375
# [89]	validation-rmse:5.74351
# [90]	validation-rmse:5.74341
# [91]	validation-rmse:5.74342
# [92]	validation-rmse:5.74330
# [93]	validation-rmse:5.74320
# [94]	validation-rmse:5.74293
# [95]	validation-rmse:5.74260
# [96]	validation-rmse:5.74243
# [97]	validation-rmse:5.74225
# [98]	validation-rmse:5.74208
# [99]	validation-rmse:5.74200
# [100]	validation-rmse:5.74172
# [101]	validation-rmse:5.74163
# [102]	validation-rmse:5.74150
# [103]	validation-rmse:5.74142
# [104]	validation-rmse:5.74132
# [105]	validation-rmse:5.74123
# [106]	validation-rmse:5.74106
# [107]	validation-rmse:5.74098
# [108]	validation-rmse:5.74089
# [109]	validation-rmse:5.74077
# [110]	validation-rmse:5.74058
# [111]	validation-rmse:5.74042
# [112]	validation-rmse:5.74033
# [113]	validation-rmse:5.74026
# [114]	validation-rmse:5.74021
# [115]	validation-rmse:5.74009
# [116]	validation-rmse:5.73985
# [117]	validation-rmse:5.73977
# [118]	validation-rmse:5.73966
# [119]	validation-rmse:5.73956
# [120]	validation-rmse:5.73949
# [121]	validation-rmse:5.73946
# [122]	validation-rmse:5.73942
# [123]	validation-rmse:5.73930
# [124]	validation-rmse:5.73904
# [125]	validation-rmse:5.73893
# [126]	validation-rmse:5.73893
# [127]	validation-rmse:5.73887
# [128]	validation-rmse:5.73882
# [129]	validation-rmse:5.73884
# [130]	validation-rmse:5.73877
# [131]	validation-rmse:5.73864
# [132]	validation-rmse:5.73858
# [133]	validation-rmse:5.73835
# [134]	validation-rmse:5.73833
# [135]	validation-rmse:5.73825
# [136]	validation-rmse:5.73805
# [137]	validation-rmse:5.73799
# [138]	validation-rmse:5.73793
# [139]	validation-rmse:5.73798
# [140]	validation-rmse:5.73775
# [141]	validation-rmse:5.73754
# [142]	validation-rmse:5.73743
# [143]	validation-rmse:5.73729
# [144]	validation-rmse:5.73720
# [145]	validation-rmse:5.73715
# [146]	validation-rmse:5.73706
# [147]	validation-rmse:5.73707
# [148]	validation-rmse:5.73700
# [149]	validation-rmse:5.73689
# [150]	validation-rmse:5.73678
# [151]	validation-rmse:5.73660
# [152]	validation-rmse:5.73649
# [153]	validation-rmse:5.73643
# [154]	validation-rmse:5.73620
# [155]	validation-rmse:5.73608
# [156]	validation-rmse:5.73601
# [157]	validation-rmse:5.73595
# [158]	validation-rmse:5.73590
# [159]	validation-rmse:5.73582
# [160]	validation-rmse:5.73572
# [161]	validation-rmse:5.73562
# [162]	validation-rmse:5.73567
# [163]	validation-rmse:5.73552
# [164]	validation-rmse:5.73541
# [165]	validation-rmse:5.73535
# [166]	validation-rmse:5.73524
# [167]	validation-rmse:5.73510
# [168]	validation-rmse:5.73501
# [169]	validation-rmse:5.73495
# [170]	validation-rmse:5.73496
# [171]	validation-rmse:5.73485
# [172]	validation-rmse:5.73480
# [173]	validation-rmse:5.73470
# [174]	validation-rmse:5.73463
# [175]	validation-rmse:5.73447
# [176]	validation-rmse:5.73441
# [177]	validation-rmse:5.73450
# [178]	validation-rmse:5.73441
# [179]	validation-rmse:5.73442
# [180]	validation-rmse:5.73431
# [181]	validation-rmse:5.73423
# [182]	validation-rmse:5.73424
# [183]	validation-rmse:5.73428
# [184]	validation-rmse:5.73419
# [185]	validation-rmse:5.73409
# [186]	validation-rmse:5.73399
# [187]	validation-rmse:5.73392
# [188]	validation-rmse:5.73376
# [189]	validation-rmse:5.73366
# [190]	validation-rmse:5.73359
# [191]	validation-rmse:5.73354
# [192]	validation-rmse:5.73348
# [193]	validation-rmse:5.73341
# [194]	validation-rmse:5.73337
# [195]	validation-rmse:5.73306
# [196]	validation-rmse:5.73301
# [197]	validation-rmse:5.73294
# [198]	validation-rmse:5.73282
# [199]	validation-rmse:5.73274
# [200]	validation-rmse:5.73266
# [201]	validation-rmse:5.73257
# [202]	validation-rmse:5.73246
# [203]	validation-rmse:5.73238
# [204]	validation-rmse:5.73231
# [205]	validation-rmse:5.73225
# [206]	validation-rmse:5.73215
# [207]	validation-rmse:5.73206
# [208]	validation-rmse:5.73198
# [209]	validation-rmse:5.73188
# [210]	validation-rmse:5.73182
# [211]	validation-rmse:5.73169
# [212]	validation-rmse:5.73151
# [213]	validation-rmse:5.73136
# [214]	validation-rmse:5.73123
# [215]	validation-rmse:5.73119
# [216]	validation-rmse:5.73109
# [217]	validation-rmse:5.73094
# [218]	validation-rmse:5.73082
# [219]	validation-rmse:5.73072
# [220]	validation-rmse:5.73068
# [221]	validation-rmse:5.73064
# [222]	validation-rmse:5.73061
# [223]	validation-rmse:5.73057
# [224]	validation-rmse:5.73054
# [225]	validation-rmse:5.73048
# [226]	validation-rmse:5.73042
# [227]	validation-rmse:5.73033
# [228]	validation-rmse:5.73024
# [229]	validation-rmse:5.73017
# [230]	validation-rmse:5.73013
# [231]	validation-rmse:5.73009
# [232]	validation-rmse:5.73001
# [233]	validation-rmse:5.72994
# [234]	validation-rmse:5.72989
# [235]	validation-rmse:5.72981
# [236]	validation-rmse:5.72972
# [237]	validation-rmse:5.72966
# [238]	validation-rmse:5.72945
# [239]	validation-rmse:5.72939
# [240]	validation-rmse:5.72936
# [241]	validation-rmse:5.72927
# [242]	validation-rmse:5.72925
# [243]	validation-rmse:5.72917
# [244]	validation-rmse:5.72918
# [245]	validation-rmse:5.72911
# [246]	validation-rmse:5.72905
# [247]	validation-rmse:5.72893
# [248]	validation-rmse:5.72894
# [249]	validation-rmse:5.72888
# [250]	validation-rmse:5.72895
# [251]	validation-rmse:5.72898
# [252]	validation-rmse:5.72889
# [253]	validation-rmse:5.72889
# [254]	validation-rmse:5.72886
# [255]	validation-rmse:5.72867
# [256]	validation-rmse:5.72865
# [257]	validation-rmse:5.72861
# [258]	validation-rmse:5.72851
# [259]	validation-rmse:5.72850
# [260]	validation-rmse:5.72838
# [261]	validation-rmse:5.72837
# [262]	validation-rmse:5.72832
# [263]	validation-rmse:5.72829
# [264]	validation-rmse:5.72813
# [265]	validation-rmse:5.72805
# [266]	validation-rmse:5.72801
# [267]	validation-rmse:5.72795
# [268]	validation-rmse:5.72789
# [269]	validation-rmse:5.72791
# [270]	validation-rmse:5.72784
# [271]	validation-rmse:5.72777
# [272]	validation-rmse:5.72760
# [273]	validation-rmse:5.72755
# [274]	validation-rmse:5.72750
# [275]	validation-rmse:5.72737
# [276]	validation-rmse:5.72733
# [277]	validation-rmse:5.72723
# [278]	validation-rmse:5.72717
# [279]	validation-rmse:5.72708
# [280]	validation-rmse:5.72707
# [281]	validation-rmse:5.72700
# [282]	validation-rmse:5.72691
# [283]	validation-rmse:5.72686
# [284]	validation-rmse:5.72681
# [285]	validation-rmse:5.72678
# [286]	validation-rmse:5.72666
# [287]	validation-rmse:5.72653
# [288]	validation-rmse:5.72649
# [289]	validation-rmse:5.72639
# [290]	validation-rmse:5.72631
# [291]	validation-rmse:5.72626
# [292]	validation-rmse:5.72622
# [293]	validation-rmse:5.72612
# [294]	validation-rmse:5.72607
# [295]	validation-rmse:5.72600
# [296]	validation-rmse:5.72594
# [297]	validation-rmse:5.72592
# [298]	validation-rmse:5.72585
# [299]	validation-rmse:5.72579
# [300]	validation-rmse:5.72568
# [301]	validation-rmse:5.72566
# [302]	validation-rmse:5.72563
# [303]	validation-rmse:5.72555
# [304]	validation-rmse:5.72546
# [305]	validation-rmse:5.72545
# [306]	validation-rmse:5.72540
# [307]	validation-rmse:5.72539
# [308]	validation-rmse:5.72535
# [309]	validation-rmse:5.72537
# [310]	validation-rmse:5.72535
# [311]	validation-rmse:5.72528
# [312]	validation-rmse:5.72528
# [313]	validation-rmse:5.72520
# [314]	validation-rmse:5.72497
# [315]	validation-rmse:5.72490
# [316]	validation-rmse:5.72477
# [317]	validation-rmse:5.72469
# [318]	validation-rmse:5.72465
# [319]	validation-rmse:5.72466
# [320]	validation-rmse:5.72463
# [321]	validation-rmse:5.72452
# [322]	validation-rmse:5.72450
# [323]	validation-rmse:5.72442
# [324]	validation-rmse:5.72438
# [325]	validation-rmse:5.72429
# [326]	validation-rmse:5.72429
# [327]	validation-rmse:5.72431
# [328]	validation-rmse:5.72430
# [329]	validation-rmse:5.72421
# [330]	validation-rmse:5.72425
# [331]	validation-rmse:5.72421
# [332]	validation-rmse:5.72419
# [333]	validation-rmse:5.72412
# [334]	validation-rmse:5.72414
# [335]	validation-rmse:5.72405
# [336]	validation-rmse:5.72405
# [337]	validation-rmse:5.72408
# [338]	validation-rmse:5.72411
# [339]	validation-rmse:5.72402
# [340]	validation-rmse:5.72407
# [341]	validation-rmse:5.72394
# [342]	validation-rmse:5.72386
# [343]	validation-rmse:5.72385
# [344]	validation-rmse:5.72380
# [345]	validation-rmse:5.72376
# [346]	validation-rmse:5.72385
# [347]	validation-rmse:5.72379
# [348]	validation-rmse:5.72373
# [349]	validation-rmse:5.72365
# [350]	validation-rmse:5.72358
# [351]	validation-rmse:5.72363
# [352]	validation-rmse:5.72357
# [353]	validation-rmse:5.72351
# [354]	validation-rmse:5.72348
# [355]	validation-rmse:5.72345
# [356]	validation-rmse:5.72346
# [357]	validation-rmse:5.72331
# [358]	validation-rmse:5.72321
# [359]	validation-rmse:5.72325
# [360]	validation-rmse:5.72319
# [361]	validation-rmse:5.72308
# [362]	validation-rmse:5.72300
# [363]	validation-rmse:5.72292
# [364]	validation-rmse:5.72283
# [365]	validation-rmse:5.72280
# [366]	validation-rmse:5.72279
# [367]	validation-rmse:5.72276
# [368]	validation-rmse:5.72271
# [369]	validation-rmse:5.72264
# [370]	validation-rmse:5.72247
# [371]	validation-rmse:5.72237
# [372]	validation-rmse:5.72237
# [373]	validation-rmse:5.72233
# [374]	validation-rmse:5.72225
# [375]	validation-rmse:5.72219
# [376]	validation-rmse:5.72209
# [377]	validation-rmse:5.72205
# [378]	validation-rmse:5.72202
# [379]	validation-rmse:5.72200
# [380]	validation-rmse:5.72201
# [381]	validation-rmse:5.72193
# [382]	validation-rmse:5.72180
# [383]	validation-rmse:5.72177
# [384]	validation-rmse:5.72170
# [385]	validation-rmse:5.72170
# [386]	validation-rmse:5.72162
# [387]	validation-rmse:5.72154
# [388]	validation-rmse:5.72154
# [389]	validation-rmse:5.72151
# [390]	validation-rmse:5.72147
# [391]	validation-rmse:5.72146
# [392]	validation-rmse:5.72139
# [393]	validation-rmse:5.72139
# [394]	validation-rmse:5.72131
# [395]	validation-rmse:5.72132
# [396]	validation-rmse:5.72132
# [397]	validation-rmse:5.72123
# [398]	validation-rmse:5.72117
# [399]	validation-rmse:5.72110
# [400]	validation-rmse:5.72109
# [401]	validation-rmse:5.72102
# [402]	validation-rmse:5.72097
# [403]	validation-rmse:5.72093
# [404]	validation-rmse:5.72095
# [405]	validation-rmse:5.72087
# [406]	validation-rmse:5.72073
# [407]	validation-rmse:5.72073
# [408]	validation-rmse:5.72061
# [409]	validation-rmse:5.72063
# [410]	validation-rmse:5.72061
# [411]	validation-rmse:5.72055
# [412]	validation-rmse:5.72047
# [413]	validation-rmse:5.72044
# [414]	validation-rmse:5.72037
# [415]	validation-rmse:5.72028
# [416]	validation-rmse:5.72029
# [417]	validation-rmse:5.72026
# [418]	validation-rmse:5.72026
# [419]	validation-rmse:5.72017
# [420]	validation-rmse:5.72012
# [421]	validation-rmse:5.72016
# [422]	validation-rmse:5.72004
# [423]	validation-rmse:5.72003
# [424]	validation-rmse:5.71999
# [425]	validation-rmse:5.72000
# [426]	validation-rmse:5.71998
# [427]	validation-rmse:5.71998
# [428]	validation-rmse:5.72000
# [429]	validation-rmse:5.71993
# [430]	validation-rmse:5.72001
# [431]	validation-rmse:5.71974
# [432]	validation-rmse:5.71976
# [433]	validation-rmse:5.71965
# [434]	validation-rmse:5.71958
# [435]	validation-rmse:5.71945
# [436]	validation-rmse:5.71945
# [437]	validation-rmse:5.71943
# [438]	validation-rmse:5.71933
# [439]	validation-rmse:5.71927
# [440]	validation-rmse:5.71916
# [441]	validation-rmse:5.71919
# [442]	validation-rmse:5.71921
# [443]	validation-rmse:5.71914
# [444]	validation-rmse:5.71915
# [445]	validation-rmse:5.71901
# [446]	validation-rmse:5.71904
# [447]	validation-rmse:5.71904
# [448]	validation-rmse:5.71899
# [449]	validation-rmse:5.71896
# [450]	validation-rmse:5.71895
# [451]	validation-rmse:5.71880
# [452]	validation-rmse:5.71877
# [453]	validation-rmse:5.71873
# [454]	validation-rmse:5.71868
# [455]	validation-rmse:5.71858
# [456]	validation-rmse:5.71851
# [457]	validation-rmse:5.71847
# [458]	validation-rmse:5.71845
# [459]	validation-rmse:5.71840
# [460]	validation-rmse:5.71835
# [461]	validation-rmse:5.71833
# [462]	validation-rmse:5.71829
# [463]	validation-rmse:5.71828
# [464]	validation-rmse:5.71827
# [465]	validation-rmse:5.71828
# [466]	validation-rmse:5.71825
# [467]	validation-rmse:5.71815
# [468]	validation-rmse:5.71811
# [469]	validation-rmse:5.71815
# [470]	validation-rmse:5.71814
# [471]	validation-rmse:5.71820
# [472]	validation-rmse:5.71808
# [473]	validation-rmse:5.71804
# [474]	validation-rmse:5.71796
# [475]	validation-rmse:5.71788
# [476]	validation-rmse:5.71779
# [477]	validation-rmse:5.71777
# [478]	validation-rmse:5.71771
# [479]	validation-rmse:5.71766
# [480]	validation-rmse:5.71760
# [481]	validation-rmse:5.71757
# [482]	validation-rmse:5.71755
# [483]	validation-rmse:5.71760
# [484]	validation-rmse:5.71757
# [485]	validation-rmse:5.71755
# [486]	validation-rmse:5.71751
# [487]	validation-rmse:5.71745
# [488]	validation-rmse:5.71737
# [489]	validation-rmse:5.71731
# [490]	validation-rmse:5.71726
# [491]	validation-rmse:5.71722
# [492]	validation-rmse:5.71713
# [493]	validation-rmse:5.71706
# [494]	validation-rmse:5.71695
# [495]	validation-rmse:5.71695
# [496]	validation-rmse:5.71691
# [497]	validation-rmse:5.71686
# [498]	validation-rmse:5.71685
# [499]	validation-rmse:5.71675
# [500]	validation-rmse:5.71669
# [501]	validation-rmse:5.71673
# [502]	validation-rmse:5.71673
# [503]	validation-rmse:5.71673
# [504]	validation-rmse:5.71668
# [505]	validation-rmse:5.71657
# [506]	validation-rmse:5.71653
# [507]	validation-rmse:5.71653
# [508]	validation-rmse:5.71658
# [509]	validation-rmse:5.71655
# [510]	validation-rmse:5.71643
# [511]	validation-rmse:5.71636
# [512]	validation-rmse:5.71630
# [513]	validation-rmse:5.71627
# [514]	validation-rmse:5.71626
# [515]	validation-rmse:5.71620
# [516]	validation-rmse:5.71614
# [517]	validation-rmse:5.71611
# [518]	validation-rmse:5.71604
# [519]	validation-rmse:5.71604
# [520]	validation-rmse:5.71597
# [521]	validation-rmse:5.71589
# [522]	validation-rmse:5.71588
# [523]	validation-rmse:5.71587
# [524]	validation-rmse:5.71587
# [525]	validation-rmse:5.71589
# [526]	validation-rmse:5.71589
# [527]	validation-rmse:5.71582
# [528]	validation-rmse:5.71574
# [529]	validation-rmse:5.71568
# [530]	validation-rmse:5.71554
# [531]	validation-rmse:5.71549
# [532]	validation-rmse:5.71552
# [533]	validation-rmse:5.71548
# [534]	validation-rmse:5.71555
# [535]	validation-rmse:5.71550
# [536]	validation-rmse:5.71546
# [537]	validation-rmse:5.71549
# [538]	validation-rmse:5.71540
# [539]	validation-rmse:5.71531
# [540]	validation-rmse:5.71531
# [541]	validation-rmse:5.71531
# [542]	validation-rmse:5.71533
# [543]	validation-rmse:5.71527
# [544]	validation-rmse:5.71526
# [545]	validation-rmse:5.71526
# [546]	validation-rmse:5.71517
# [547]	validation-rmse:5.71515
# [548]	validation-rmse:5.71521
# [549]	validation-rmse:5.71519
# [550]	validation-rmse:5.71524
# [551]	validation-rmse:5.71524
# [552]	validation-rmse:5.71527
# [553]	validation-rmse:5.71512
# [554]	validation-rmse:5.71512
# [555]	validation-rmse:5.71506
# [556]	validation-rmse:5.71496
# [557]	validation-rmse:5.71495
# [558]	validation-rmse:5.71496
# [559]	validation-rmse:5.71487
# [560]	validation-rmse:5.71484
# [561]	validation-rmse:5.71485
# [562]	validation-rmse:5.71476
# [563]	validation-rmse:5.71474
# [564]	validation-rmse:5.71469
# [565]	validation-rmse:5.71467
# [566]	validation-rmse:5.71455
# [567]	validation-rmse:5.71447
# [568]	validation-rmse:5.71446
# [569]	validation-rmse:5.71440
# [570]	validation-rmse:5.71439
# [571]	validation-rmse:5.71431
# [572]	validation-rmse:5.71428
# [573]	validation-rmse:5.71431
# [574]	validation-rmse:5.71427
# [575]	validation-rmse:5.71421
# [576]	validation-rmse:5.71415
# [577]	validation-rmse:5.71402
# [578]	validation-rmse:5.71403
# [579]	validation-rmse:5.71395
# [580]	validation-rmse:5.71393
# [581]	validation-rmse:5.71390
# [582]	validation-rmse:5.71398
# [583]	validation-rmse:5.71400
# [584]	validation-rmse:5.71383
# [585]	validation-rmse:5.71382
# [586]	validation-rmse:5.71378
# [587]	validation-rmse:5.71371
# [588]	validation-rmse:5.71365
# [589]	validation-rmse:5.71365
# [590]	validation-rmse:5.71363
# [591]	validation-rmse:5.71360
# [592]	validation-rmse:5.71350
# [593]	validation-rmse:5.71352
# [594]	validation-rmse:5.71353
# [595]	validation-rmse:5.71351
# [596]	validation-rmse:5.71351
# [597]	validation-rmse:5.71354
# [598]	validation-rmse:5.71348
# [599]	validation-rmse:5.71340
# [600]	validation-rmse:5.71340
# [601]	validation-rmse:5.71333
# [602]	validation-rmse:5.71325
# [603]	validation-rmse:5.71318
# [604]	validation-rmse:5.71316
# [605]	validation-rmse:5.71315
# [606]	validation-rmse:5.71312
# [607]	validation-rmse:5.71309
# [608]	validation-rmse:5.71304
# [609]	validation-rmse:5.71290
# [610]	validation-rmse:5.71287
# [611]	validation-rmse:5.71282
# [612]	validation-rmse:5.71277
# [613]	validation-rmse:5.71274
# [614]	validation-rmse:5.71283
# [615]	validation-rmse:5.71280
# [616]	validation-rmse:5.71273
# [617]	validation-rmse:5.71266
# [618]	validation-rmse:5.71263
# [619]	validation-rmse:5.71255
# [620]	validation-rmse:5.71252
# [621]	validation-rmse:5.71248
# [622]	validation-rmse:5.71241
# [623]	validation-rmse:5.71234
# [624]	validation-rmse:5.71230
# [625]	validation-rmse:5.71223
# [626]	validation-rmse:5.71216
# [627]	validation-rmse:5.71215
# [628]	validation-rmse:5.71217
# [629]	validation-rmse:5.71214
# [630]	validation-rmse:5.71215
# [631]	validation-rmse:5.71215
# [632]	validation-rmse:5.71205
# [633]	validation-rmse:5.71202
# [634]	validation-rmse:5.71192
# [635]	validation-rmse:5.71188
# [636]	validation-rmse:5.71187
# [637]	validation-rmse:5.71192
# [638]	validation-rmse:5.71189
# [639]	validation-rmse:5.71184
# [640]	validation-rmse:5.71182
# [641]	validation-rmse:5.71181
# [642]	validation-rmse:5.71180
# [643]	validation-rmse:5.71184
# [644]	validation-rmse:5.71177
# [645]	validation-rmse:5.71172
# [646]	validation-rmse:5.71168
# [647]	validation-rmse:5.71175
# [648]	validation-rmse:5.71170
# [649]	validation-rmse:5.71165
# [650]	validation-rmse:5.71162
# [651]	validation-rmse:5.71155
# [652]	validation-rmse:5.71147
# [653]	validation-rmse:5.71147
# [654]	validation-rmse:5.71145
# [655]	validation-rmse:5.71142
# [656]	validation-rmse:5.71134
# [657]	validation-rmse:5.71141
# [658]	validation-rmse:5.71136
# [659]	validation-rmse:5.71131
# [660]	validation-rmse:5.71127
# [661]	validation-rmse:5.71120
# [662]	validation-rmse:5.71109
# [663]	validation-rmse:5.71106
# [664]	validation-rmse:5.71109
# [665]	validation-rmse:5.71102
# [666]	validation-rmse:5.71095
# [667]	validation-rmse:5.71090
# [668]	validation-rmse:5.71097
# [669]	validation-rmse:5.71099
# [670]	validation-rmse:5.71099
# [671]	validation-rmse:5.71085
# [672]	validation-rmse:5.71086
# [673]	validation-rmse:5.71083
# [674]	validation-rmse:5.71086
# [675]	validation-rmse:5.71092
# [676]	validation-rmse:5.71094
# [677]	validation-rmse:5.71095
# [678]	validation-rmse:5.71098
# [679]	validation-rmse:5.71094
# [680]	validation-rmse:5.71090
# [681]	validation-rmse:5.71082
# [682]	validation-rmse:5.71084
# [683]	validation-rmse:5.71076
# [684]	validation-rmse:5.71079
# [685]	validation-rmse:5.71072
# [686]	validation-rmse:5.71071
# [687]	validation-rmse:5.71065
# [688]	validation-rmse:5.71064
# [689]	validation-rmse:5.71065
# [690]	validation-rmse:5.71064
# [691]	validation-rmse:5.71060
# [692]	validation-rmse:5.71058
# [693]	validation-rmse:5.71060
# [694]	validation-rmse:5.71061
# [695]	validation-rmse:5.71061
# [696]	validation-rmse:5.71066
# [697]	validation-rmse:5.71061
# [698]	validation-rmse:5.71053
# [699]	validation-rmse:5.71041
# [700]	validation-rmse:5.71039
# [701]	validation-rmse:5.71037
# [702]	validation-rmse:5.71031
# [703]	validation-rmse:5.71033
# [704]	validation-rmse:5.71033
# [705]	validation-rmse:5.71023
# [706]	validation-rmse:5.71019
# [707]	validation-rmse:5.71016
# [708]	validation-rmse:5.71016
# [709]	validation-rmse:5.71012
# [710]	validation-rmse:5.71006
# [711]	validation-rmse:5.71006
# [712]	validation-rmse:5.71005
# [713]	validation-rmse:5.71006
# [714]	validation-rmse:5.71003
# [715]	validation-rmse:5.70993
# [716]	validation-rmse:5.70991
# [717]	validation-rmse:5.70985
# [718]	validation-rmse:5.70978
# [719]	validation-rmse:5.70972
# [720]	validation-rmse:5.70973
# [721]	validation-rmse:5.70973
# [722]	validation-rmse:5.70963
# [723]	validation-rmse:5.70958
# [724]	validation-rmse:5.70956
# [725]	validation-rmse:5.70954
# [726]	validation-rmse:5.70956
# [727]	validation-rmse:5.70955
# [728]	validation-rmse:5.70948
# [729]	validation-rmse:5.70945
# [730]	validation-rmse:5.70939
# [731]	validation-rmse:5.70934
# [732]	validation-rmse:5.70933
# [733]	validation-rmse:5.70930
# [734]	validation-rmse:5.70930
# [735]	validation-rmse:5.70926
# [736]	validation-rmse:5.70925
# [737]	validation-rmse:5.70922
# [738]	validation-rmse:5.70912
# [739]	validation-rmse:5.70916
# [740]	validation-rmse:5.70912
# [741]	validation-rmse:5.70916
# [742]	validation-rmse:5.70919
# [743]	validation-rmse:5.70923
# [744]	validation-rmse:5.70924
# [745]	validation-rmse:5.70919
# [746]	validation-rmse:5.70913
# [747]	validation-rmse:5.70907
# [748]	validation-rmse:5.70908
# [749]	validation-rmse:5.70907
# [750]	validation-rmse:5.70905
# [751]	validation-rmse:5.70896
# [752]	validation-rmse:5.70891
# [753]	validation-rmse:5.70891
# [754]	validation-rmse:5.70889
# [755]	validation-rmse:5.70890
# [756]	validation-rmse:5.70880
# [757]	validation-rmse:5.70875
# [758]	validation-rmse:5.70872
# [759]	validation-rmse:5.70875
# [760]	validation-rmse:5.70871
# [761]	validation-rmse:5.70869
# [762]	validation-rmse:5.70871
# [763]	validation-rmse:5.70867
# [764]	validation-rmse:5.70859
# [765]	validation-rmse:5.70851
# [766]	validation-rmse:5.70844
# [767]	validation-rmse:5.70842
# [768]	validation-rmse:5.70840
# [769]	validation-rmse:5.70833
# [770]	validation-rmse:5.70829
# [771]	validation-rmse:5.70827
# [772]	validation-rmse:5.70830
# [773]	validation-rmse:5.70830
# [774]	validation-rmse:5.70829
# [775]	validation-rmse:5.70816
# [776]	validation-rmse:5.70811
# [777]	validation-rmse:5.70808
# [778]	validation-rmse:5.70804
# [779]	validation-rmse:5.70800
# [780]	validation-rmse:5.70811
# [781]	validation-rmse:5.70805
# [782]	validation-rmse:5.70809
# [783]	validation-rmse:5.70808
# [784]	validation-rmse:5.70806
# [785]	validation-rmse:5.70807
# [786]	validation-rmse:5.70805
# [787]	validation-rmse:5.70797
# [788]	validation-rmse:5.70794
# [789]	validation-rmse:5.70792
# [790]	validation-rmse:5.70788
# [791]	validation-rmse:5.70783
# [792]	validation-rmse:5.70771
# [793]	validation-rmse:5.70765
# [794]	validation-rmse:5.70761
# [795]	validation-rmse:5.70758
# [796]	validation-rmse:5.70764
# [797]	validation-rmse:5.70762
# [798]	validation-rmse:5.70755
# [799]	validation-rmse:5.70754
# [800]	validation-rmse:5.70748
# [801]	validation-rmse:5.70750
# [802]	validation-rmse:5.70744
# [803]	validation-rmse:5.70742
# [804]	validation-rmse:5.70745
# [805]	validation-rmse:5.70744
# [806]	validation-rmse:5.70740
# [807]	validation-rmse:5.70742
# [808]	validation-rmse:5.70745
# [809]	validation-rmse:5.70744
# [810]	validation-rmse:5.70742
# [811]	validation-rmse:5.70736
# [812]	validation-rmse:5.70735
# [813]	validation-rmse:5.70737
# [814]	validation-rmse:5.70735
# [815]	validation-rmse:5.70727
# [816]	validation-rmse:5.70721
# [817]	validation-rmse:5.70716
# [818]	validation-rmse:5.70717
# [819]	validation-rmse:5.70716
# [820]	validation-rmse:5.70711
# [821]	validation-rmse:5.70705
# [822]	validation-rmse:5.70701
# [823]	validation-rmse:5.70702
# [824]	validation-rmse:5.70698
# [825]	validation-rmse:5.70697
# [826]	validation-rmse:5.70693
# [827]	validation-rmse:5.70698
# [828]	validation-rmse:5.70693
# [829]	validation-rmse:5.70690
# [830]	validation-rmse:5.70689
# [831]	validation-rmse:5.70685
# [832]	validation-rmse:5.70692
# [833]	validation-rmse:5.70690
# [834]	validation-rmse:5.70692
# [835]	validation-rmse:5.70687
# [836]	validation-rmse:5.70685
# [837]	validation-rmse:5.70680
# [838]	validation-rmse:5.70679
# [839]	validation-rmse:5.70683
# [840]	validation-rmse:5.70676
# [841]	validation-rmse:5.70678
# [842]	validation-rmse:5.70675
# [843]	validation-rmse:5.70666
# [844]	validation-rmse:5.70662
# [845]	validation-rmse:5.70653
# [846]	validation-rmse:5.70638
# [847]	validation-rmse:5.70636
# [848]	validation-rmse:5.70634
# [849]	validation-rmse:5.70635
# [850]	validation-rmse:5.70635
# [851]	validation-rmse:5.70632
# [852]	validation-rmse:5.70635
# [853]	validation-rmse:5.70635
# [854]	validation-rmse:5.70637
# [855]	validation-rmse:5.70632
# [856]	validation-rmse:5.70632
# [857]	validation-rmse:5.70631
# [858]	validation-rmse:5.70630
# [859]	validation-rmse:5.70628
# [860]	validation-rmse:5.70626
# [861]	validation-rmse:5.70621
# [862]	validation-rmse:5.70620
# [863]	validation-rmse:5.70614
# [864]	validation-rmse:5.70613
# [865]	validation-rmse:5.70614
# [866]	validation-rmse:5.70599
# [867]	validation-rmse:5.70594
# [868]	validation-rmse:5.70594
# [869]	validation-rmse:5.70589
# [870]	validation-rmse:5.70588
# [871]	validation-rmse:5.70586
# [872]	validation-rmse:5.70584
# [873]	validation-rmse:5.70579
# [874]	validation-rmse:5.70578
# [875]	validation-rmse:5.70591
# [876]	validation-rmse:5.70590
# [877]	validation-rmse:5.70590
# [878]	validation-rmse:5.70578
# [879]	validation-rmse:5.70572
# [880]	validation-rmse:5.70571
# [881]	validation-rmse:5.70569
# [882]	validation-rmse:5.70568
# [883]	validation-rmse:5.70566
# [884]	validation-rmse:5.70563
# [885]	validation-rmse:5.70563
# [886]	validation-rmse:5.70563
# [887]	validation-rmse:5.70559
# [888]	validation-rmse:5.70558
# [889]	validation-rmse:5.70553
# [890]	validation-rmse:5.70547
# [891]	validation-rmse:5.70542
# [892]	validation-rmse:5.70536
# [893]	validation-rmse:5.70537
# [894]	validation-rmse:5.70537
# [895]	validation-rmse:5.70536
# [896]	validation-rmse:5.70533
# [897]	validation-rmse:5.70530
# [898]	validation-rmse:5.70526
# [899]	validation-rmse:5.70523
# [900]	validation-rmse:5.70520
# [901]	validation-rmse:5.70521
# [902]	validation-rmse:5.70523
# [903]	validation-rmse:5.70522
# [904]	validation-rmse:5.70521
# [905]	validation-rmse:5.70519
# [906]	validation-rmse:5.70515
# [907]	validation-rmse:5.70511
# [908]	validation-rmse:5.70507
# [909]	validation-rmse:5.70502
# [910]	validation-rmse:5.70495
# [911]	validation-rmse:5.70500
# [912]	validation-rmse:5.70496
# [913]	validation-rmse:5.70495
# [914]	validation-rmse:5.70494
# [915]	validation-rmse:5.70492
# [916]	validation-rmse:5.70492
# [917]	validation-rmse:5.70486
# [918]	validation-rmse:5.70486
# [919]	validation-rmse:5.70484
# [920]	validation-rmse:5.70477
# [921]	validation-rmse:5.70472
# [922]	validation-rmse:5.70462
# [923]	validation-rmse:5.70456
# [924]	validation-rmse:5.70459
# [925]	validation-rmse:5.70455
# [926]	validation-rmse:5.70458
# [927]	validation-rmse:5.70456
# [928]	validation-rmse:5.70459
# [929]	validation-rmse:5.70455
# [930]	validation-rmse:5.70438
# [931]	validation-rmse:5.70437
# [932]	validation-rmse:5.70427
# [933]	validation-rmse:5.70427
# [934]	validation-rmse:5.70426
# [935]	validation-rmse:5.70422
# [936]	validation-rmse:5.70415
# [937]	validation-rmse:5.70414
# [938]	validation-rmse:5.70410
# [939]	validation-rmse:5.70407
# [940]	validation-rmse:5.70401
# [941]	validation-rmse:5.70404
# [942]	validation-rmse:5.70409
# [943]	validation-rmse:5.70404
# [944]	validation-rmse:5.70403
# [945]	validation-rmse:5.70399
# [946]	validation-rmse:5.70400
# [947]	validation-rmse:5.70400
# [948]	validation-rmse:5.70401
# [949]	validation-rmse:5.70398
# [950]	validation-rmse:5.70399
# [951]	validation-rmse:5.70398
# [952]	validation-rmse:5.70405
# [953]	validation-rmse:5.70402
# [954]	validation-rmse:5.70405
# [955]	validation-rmse:5.70398
# [956]	validation-rmse:5.70397
# [957]	validation-rmse:5.70392
# [958]	validation-rmse:5.70387
# [959]	validation-rmse:5.70382
# [960]	validation-rmse:5.70381
# [961]	validation-rmse:5.70376
# [962]	validation-rmse:5.70371
# [963]	validation-rmse:5.70371
# [964]	validation-rmse:5.70367
# [965]	validation-rmse:5.70366
# [966]	validation-rmse:5.70363
# [967]	validation-rmse:5.70360
# [968]	validation-rmse:5.70364
# [969]	validation-rmse:5.70364
# [970]	validation-rmse:5.70360
# [971]	validation-rmse:5.70357
# [972]	validation-rmse:5.70355
# [973]	validation-rmse:5.70352
# [974]	validation-rmse:5.70350
# [975]	validation-rmse:5.70352
# [976]	validation-rmse:5.70346
# [977]	validation-rmse:5.70354
# [978]	validation-rmse:5.70357
# [979]	validation-rmse:5.70364
# [980]	validation-rmse:5.70361
# [981]	validation-rmse:5.70354
# [982]	validation-rmse:5.70353
# [983]	validation-rmse:5.70350
# [984]	validation-rmse:5.70346
# [985]	validation-rmse:5.70343
# [986]	validation-rmse:5.70337
# [987]	validation-rmse:5.70336
# [988]	validation-rmse:5.70329
# [989]	validation-rmse:5.70329
# [990]	validation-rmse:5.70332
# [991]	validation-rmse:5.70337
# [992]	validation-rmse:5.70338
# [993]	validation-rmse:5.70331
# [994]	validation-rmse:5.70329
# [995]	validation-rmse:5.70327
# [996]	validation-rmse:5.70327
# [997]	validation-rmse:5.70322
# [998]	validation-rmse:5.70325
# [999]	validation-rmse:5.70321
# /home/mlops/anaconda3/envs/mlops_bootcamp_env/lib/python3.9/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
