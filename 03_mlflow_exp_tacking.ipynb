# %%
# !python -V
# Out:
# Python 3.9.13

# %%
# data manipulation and storage
import pandas as pd

# plotting and graphs
import seaborn as sns
import matplotlib.pyplot as plt

# data preprocessing
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import StandardScaler

# models
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
import xgboost as xgb

# model performance metrics
from sklearn.metrics import mean_squared_error

# saving model to file
import pickle

# mlflow for experiment tracking
import mlflow
mlflow.set_tracking_uri('sqlite:///mlflow.db')
mlflow.set_experiment('nyc-taxi-duration-experiment')

# hyper-parameter optimization
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
df_train = pd.read_parquet('./data/train_data.parquet')
df_val = pd.read_parquet('./data/validation_data.parquet')

# %%
categorical = ['PU_DO_pair']
# ['PULocationID','DOLocationID']
numerical = ['trip_distance','fare_amount']
target = 'duration'
# Pre Processing - Numerical
scaler = StandardScaler()
df_train[numerical] = scaler.fit_transform(df_train[numerical])
df_val[numerical] = scaler.transform(df_val[numerical])
train_dicts = df_train[categorical+numerical].to_dict(orient='records')
val_dicts = df_val[categorical+numerical].to_dict(orient='records')
# Pre Processing - Categorical
df_train[categorical] = df_train[categorical].astype(str)
df_val[categorical] = df_val[categorical].astype(str)
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)
y_train = df_train[target].values
X_val = dv.transform(val_dicts)
y_val = df_val[target].values

# %%
train = xgb.DMatrix(X_train,label=y_train)
valid = xgb.DMatrix(X_val, label = y_val)

# %%
# define objective function
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag('model','xgboost')
        mlflow.log_params(params)
        xgb_model = xgb.train(
            params = params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid,'validation')],
            early_stopping_rounds=50
        )
        y_pred = xgb_model.predict(valid)
        rmse = mean_squared_error(y_val,y_pred,squared=False)
        mlflow.log_metric('rmse',rmse)

    return {'loss':rmse,'status':STATUS_OK}

# define hyper-parameter search space
search_space = {
    'max_depth':scope.int(hp.quniform('max_depth',4,100,1)),
    'learning_rate':hp.loguniform('learning_rate',-3,0),
    'reg_alpha':hp.loguniform('reg_alpha',-5,-1),
    'reg_lambda':hp.loguniform('reg_lambda',-6,-1),
    'min_child_weight':hp.loguniform('min_child_weight',-1,3),
    'objective':'reg:linear',
    'seed':42
}

# Perform 50 Trials
best_result = fmin(
    fn = objective,
    space = search_space,
    algo = tpe.suggest,
    max_evals=50,
    trials = Trials()
)

# %%
# Perform single trial
# with Auto Logging for MLFlow enabled

params = {
    'learning_rate'	:0.1700079110741563,
    'max_depth':	16,
    'min_child_weight':2.37717271395477,
    'objective':	'reg:linear',
    'reg_alpha':	0.363258077609188,
    'reg_lambda':	0.011733914718256189,
    'seed':	42
}

mlflow.xgboost.autolog()

xgb.train(
    params = params,
    dtrain = train,
    num_boost_round = 1000,
    evals = [(valid,'validation')],
    early_stopping_rounds = 50
)
# Out:
# 2022/10/20 08:17:29 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'e4bd2f876e48428aa3590f2978e95aaf', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [08:17:29] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:19.16700
# [1]	validation-rmse:16.45230
# [2]	validation-rmse:14.23091
# [3]	validation-rmse:12.44161
# [4]	validation-rmse:11.00238
# [5]	validation-rmse:9.86649
# [6]	validation-rmse:8.95757
# [7]	validation-rmse:8.24955
# [8]	validation-rmse:7.69220
# [9]	validation-rmse:7.27076
# [10]	validation-rmse:6.94454
# [11]	validation-rmse:6.68103
# [12]	validation-rmse:6.47129
# [13]	validation-rmse:6.31366
# [14]	validation-rmse:6.18344
# [15]	validation-rmse:6.08396
# [16]	validation-rmse:6.01352
# [17]	validation-rmse:5.94952
# [18]	validation-rmse:5.90587
# [19]	validation-rmse:5.86713
# [20]	validation-rmse:5.82054
# [21]	validation-rmse:5.79967
# [22]	validation-rmse:5.78225
# [23]	validation-rmse:5.76755
# [24]	validation-rmse:5.75323
# [25]	validation-rmse:5.74527
# [26]	validation-rmse:5.73492
# [27]	validation-rmse:5.72813
# [28]	validation-rmse:5.72246
# [29]	validation-rmse:5.71917
# [30]	validation-rmse:5.71479
# [31]	validation-rmse:5.71183
# [32]	validation-rmse:5.70939
# [33]	validation-rmse:5.70770
# [34]	validation-rmse:5.70610
# [35]	validation-rmse:5.70457
# [36]	validation-rmse:5.70234
# [37]	validation-rmse:5.70105
# [38]	validation-rmse:5.69993
# [39]	validation-rmse:5.69950
# [40]	validation-rmse:5.69840
# [41]	validation-rmse:5.69769
# [42]	validation-rmse:5.69710
# [43]	validation-rmse:5.69622
# [44]	validation-rmse:5.69577
# [45]	validation-rmse:5.69507
# [46]	validation-rmse:5.69432
# [47]	validation-rmse:5.69356
# [48]	validation-rmse:5.69319
# [49]	validation-rmse:5.69274
# [50]	validation-rmse:5.69189
# [51]	validation-rmse:5.69124
# [52]	validation-rmse:5.69031
# [53]	validation-rmse:5.68957
# [54]	validation-rmse:5.68920
# [55]	validation-rmse:5.68829
# [56]	validation-rmse:5.68802
# [57]	validation-rmse:5.68787
# [58]	validation-rmse:5.68752
# [59]	validation-rmse:5.68710
# [60]	validation-rmse:5.68661
# [61]	validation-rmse:5.68654
# [62]	validation-rmse:5.68608
# [63]	validation-rmse:5.68548
# [64]	validation-rmse:5.68488
# [65]	validation-rmse:5.68476
# [66]	validation-rmse:5.68437
# [67]	validation-rmse:5.68415
# [68]	validation-rmse:5.68369
# [69]	validation-rmse:5.68334
# [70]	validation-rmse:5.68287
# [71]	validation-rmse:5.68254
# [72]	validation-rmse:5.68221
# [73]	validation-rmse:5.68187
# [74]	validation-rmse:5.68118
# [75]	validation-rmse:5.68107
# [76]	validation-rmse:5.68092
# [77]	validation-rmse:5.68067
# [78]	validation-rmse:5.68024
# [79]	validation-rmse:5.68004
# [80]	validation-rmse:5.67959
# [81]	validation-rmse:5.67933
# [82]	validation-rmse:5.67890
# [83]	validation-rmse:5.67859
# [84]	validation-rmse:5.67833
# [85]	validation-rmse:5.67810
# [86]	validation-rmse:5.67801
# [87]	validation-rmse:5.67729
# [88]	validation-rmse:5.67706
# [89]	validation-rmse:5.67657
# [90]	validation-rmse:5.67578
# [91]	validation-rmse:5.67576
# [92]	validation-rmse:5.67554
# [93]	validation-rmse:5.67534
# [94]	validation-rmse:5.67436
# [95]	validation-rmse:5.67445
# [96]	validation-rmse:5.67401
# [97]	validation-rmse:5.67405
# [98]	validation-rmse:5.67382
# [99]	validation-rmse:5.67322
# [100]	validation-rmse:5.67287
# [101]	validation-rmse:5.67255
# [102]	validation-rmse:5.67253
# [103]	validation-rmse:5.67240
# [104]	validation-rmse:5.67228
# [105]	validation-rmse:5.67211
# [106]	validation-rmse:5.67197
# [107]	validation-rmse:5.67159
# [108]	validation-rmse:5.67154
# [109]	validation-rmse:5.67051
# [110]	validation-rmse:5.67025
# [111]	validation-rmse:5.67009
# [112]	validation-rmse:5.66999
# [113]	validation-rmse:5.66963
# [114]	validation-rmse:5.66961
# [115]	validation-rmse:5.66934
# [116]	validation-rmse:5.66924
# [117]	validation-rmse:5.66899
# [118]	validation-rmse:5.66862
# [119]	validation-rmse:5.66839
# [120]	validation-rmse:5.66813
# [121]	validation-rmse:5.66781
# [122]	validation-rmse:5.66746
# [123]	validation-rmse:5.66718
# [124]	validation-rmse:5.66674
# [125]	validation-rmse:5.66638
# [126]	validation-rmse:5.66611
# [127]	validation-rmse:5.66584
# [128]	validation-rmse:5.66575
# [129]	validation-rmse:5.66567
# [130]	validation-rmse:5.66548
# [131]	validation-rmse:5.66505
# [132]	validation-rmse:5.66470
# [133]	validation-rmse:5.66432
# [134]	validation-rmse:5.66411
# [135]	validation-rmse:5.66388
# [136]	validation-rmse:5.66374
# [137]	validation-rmse:5.66356
# [138]	validation-rmse:5.66317
# [139]	validation-rmse:5.66285
# [140]	validation-rmse:5.66274
# [141]	validation-rmse:5.66271
# [142]	validation-rmse:5.66206
# [143]	validation-rmse:5.66174
# [144]	validation-rmse:5.66169
# [145]	validation-rmse:5.66141
# [146]	validation-rmse:5.66087
# [147]	validation-rmse:5.66066
# [148]	validation-rmse:5.66028
# [149]	validation-rmse:5.66020
# [150]	validation-rmse:5.66011
# [151]	validation-rmse:5.65975
# [152]	validation-rmse:5.65954
# [153]	validation-rmse:5.65916
# [154]	validation-rmse:5.65864
# [155]	validation-rmse:5.65850
# [156]	validation-rmse:5.65819
# [157]	validation-rmse:5.65773
# [158]	validation-rmse:5.65768
# [159]	validation-rmse:5.65757
# [160]	validation-rmse:5.65742
# [161]	validation-rmse:5.65736
# [162]	validation-rmse:5.65694
# [163]	validation-rmse:5.65672
# [164]	validation-rmse:5.65628
# [165]	validation-rmse:5.65617
# [166]	validation-rmse:5.65595
# [167]	validation-rmse:5.65597
# [168]	validation-rmse:5.65603
# [169]	validation-rmse:5.65568
# [170]	validation-rmse:5.65543
# [171]	validation-rmse:5.65537
# [172]	validation-rmse:5.65519
# [173]	validation-rmse:5.65510
# [174]	validation-rmse:5.65508
# [175]	validation-rmse:5.65479
# [176]	validation-rmse:5.65471
# [177]	validation-rmse:5.65460
# [178]	validation-rmse:5.65445
# [179]	validation-rmse:5.65411
# [180]	validation-rmse:5.65405
# [181]	validation-rmse:5.65393
# [182]	validation-rmse:5.65368
# [183]	validation-rmse:5.65367
# [184]	validation-rmse:5.65343
# [185]	validation-rmse:5.65306
# [186]	validation-rmse:5.65279
# [187]	validation-rmse:5.65290
# [188]	validation-rmse:5.65287
# [189]	validation-rmse:5.65274
# [190]	validation-rmse:5.65231
# [191]	validation-rmse:5.65221
# [192]	validation-rmse:5.65194
# [193]	validation-rmse:5.65192
# [194]	validation-rmse:5.65183
# [195]	validation-rmse:5.65152
# [196]	validation-rmse:5.65138
# [197]	validation-rmse:5.65097
# [198]	validation-rmse:5.65080
# [199]	validation-rmse:5.65068
# [200]	validation-rmse:5.65040
# [201]	validation-rmse:5.65027
# [202]	validation-rmse:5.65007
# [203]	validation-rmse:5.64983
# [204]	validation-rmse:5.64958
# [205]	validation-rmse:5.64943
# [206]	validation-rmse:5.64934
# [207]	validation-rmse:5.64915
# [208]	validation-rmse:5.64882
# [209]	validation-rmse:5.64853
# [210]	validation-rmse:5.64845
# [211]	validation-rmse:5.64827
# [212]	validation-rmse:5.64809
# [213]	validation-rmse:5.64776
# [214]	validation-rmse:5.64751
# [215]	validation-rmse:5.64740
# [216]	validation-rmse:5.64721
# [217]	validation-rmse:5.64702
# [218]	validation-rmse:5.64672
# [219]	validation-rmse:5.64662
# [220]	validation-rmse:5.64646
# [221]	validation-rmse:5.64636
# [222]	validation-rmse:5.64620
# [223]	validation-rmse:5.64589
# [224]	validation-rmse:5.64560
# [225]	validation-rmse:5.64507
# [226]	validation-rmse:5.64485
# [227]	validation-rmse:5.64452
# [228]	validation-rmse:5.64438
# [229]	validation-rmse:5.64415
# [230]	validation-rmse:5.64417
# [231]	validation-rmse:5.64410
# [232]	validation-rmse:5.64388
# [233]	validation-rmse:5.64368
# [234]	validation-rmse:5.64339
# [235]	validation-rmse:5.64343
# [236]	validation-rmse:5.64329
# [237]	validation-rmse:5.64314
# [238]	validation-rmse:5.64311
# [239]	validation-rmse:5.64279
# [240]	validation-rmse:5.64261
# [241]	validation-rmse:5.64253
# [242]	validation-rmse:5.64235
# [243]	validation-rmse:5.64228
# [244]	validation-rmse:5.64221
# [245]	validation-rmse:5.64174
# [246]	validation-rmse:5.64160
# [247]	validation-rmse:5.64128
# [248]	validation-rmse:5.64131
# [249]	validation-rmse:5.64114
# [250]	validation-rmse:5.64044
# [251]	validation-rmse:5.64008
# [252]	validation-rmse:5.64002
# [253]	validation-rmse:5.63981
# [254]	validation-rmse:5.63947
# [255]	validation-rmse:5.63938
# [256]	validation-rmse:5.63918
# [257]	validation-rmse:5.63892
# [258]	validation-rmse:5.63894
# [259]	validation-rmse:5.63896
# [260]	validation-rmse:5.63907
# [261]	validation-rmse:5.63887
# [262]	validation-rmse:5.63882
# [263]	validation-rmse:5.63885
# [264]	validation-rmse:5.63875
# [265]	validation-rmse:5.63853
# [266]	validation-rmse:5.63798
# [267]	validation-rmse:5.63773
# [268]	validation-rmse:5.63760
# [269]	validation-rmse:5.63750
# [270]	validation-rmse:5.63747
# [271]	validation-rmse:5.63737
# [272]	validation-rmse:5.63745
# [273]	validation-rmse:5.63739
# [274]	validation-rmse:5.63724
# [275]	validation-rmse:5.63717
# [276]	validation-rmse:5.63716
# [277]	validation-rmse:5.63702
# [278]	validation-rmse:5.63671
# [279]	validation-rmse:5.63650
# [280]	validation-rmse:5.63623
# [281]	validation-rmse:5.63613
# [282]	validation-rmse:5.63595
# [283]	validation-rmse:5.63592
# [284]	validation-rmse:5.63575
# [285]	validation-rmse:5.63562
# [286]	validation-rmse:5.63554
# [287]	validation-rmse:5.63563
# [288]	validation-rmse:5.63560
# [289]	validation-rmse:5.63557
# [290]	validation-rmse:5.63516
# [291]	validation-rmse:5.63505
# [292]	validation-rmse:5.63488
# [293]	validation-rmse:5.63483
# [294]	validation-rmse:5.63465
# [295]	validation-rmse:5.63433
# [296]	validation-rmse:5.63425
# [297]	validation-rmse:5.63403
# [298]	validation-rmse:5.63397
# [299]	validation-rmse:5.63374
# [300]	validation-rmse:5.63357
# [301]	validation-rmse:5.63350
# [302]	validation-rmse:5.63336
# [303]	validation-rmse:5.63319
# [304]	validation-rmse:5.63301
# [305]	validation-rmse:5.63301
# [306]	validation-rmse:5.63289
# [307]	validation-rmse:5.63265
# [308]	validation-rmse:5.63252
# [309]	validation-rmse:5.63233
# [310]	validation-rmse:5.63211
# [311]	validation-rmse:5.63195
# [312]	validation-rmse:5.63180
# [313]	validation-rmse:5.63161
# [314]	validation-rmse:5.63175
# [315]	validation-rmse:5.63120
# [316]	validation-rmse:5.63111
# [317]	validation-rmse:5.63090
# [318]	validation-rmse:5.63075
# [319]	validation-rmse:5.63060
# [320]	validation-rmse:5.63051
# [321]	validation-rmse:5.63041
# [322]	validation-rmse:5.63026
# [323]	validation-rmse:5.63028
# [324]	validation-rmse:5.63007
# [325]	validation-rmse:5.62985
# [326]	validation-rmse:5.62972
# [327]	validation-rmse:5.62861
# [328]	validation-rmse:5.62848
# [329]	validation-rmse:5.62836
# [330]	validation-rmse:5.62822
# [331]	validation-rmse:5.62814
# [332]	validation-rmse:5.62808
# [333]	validation-rmse:5.62788
# [334]	validation-rmse:5.62787
# [335]	validation-rmse:5.62784
# [336]	validation-rmse:5.62773
# [337]	validation-rmse:5.62761
# [338]	validation-rmse:5.62761
# [339]	validation-rmse:5.62735
# [340]	validation-rmse:5.62726
# [341]	validation-rmse:5.62697
# [342]	validation-rmse:5.62686
# [343]	validation-rmse:5.62692
# [344]	validation-rmse:5.62679
# [345]	validation-rmse:5.62672
# [346]	validation-rmse:5.62662
# [347]	validation-rmse:5.62653
# [348]	validation-rmse:5.62647
# [349]	validation-rmse:5.62636
# [350]	validation-rmse:5.62626
# [351]	validation-rmse:5.62614
# [352]	validation-rmse:5.62605
# [353]	validation-rmse:5.62587
# [354]	validation-rmse:5.62565
# [355]	validation-rmse:5.62557
# [356]	validation-rmse:5.62553
# [357]	validation-rmse:5.62532
# [358]	validation-rmse:5.62545
# [359]	validation-rmse:5.62508
# [360]	validation-rmse:5.62490
# [361]	validation-rmse:5.62481
# [362]	validation-rmse:5.62469
# [363]	validation-rmse:5.62454
# [364]	validation-rmse:5.62426
# [365]	validation-rmse:5.62407
# [366]	validation-rmse:5.62401
# [367]	validation-rmse:5.62394
# [368]	validation-rmse:5.62386
# [369]	validation-rmse:5.62372
# [370]	validation-rmse:5.62369
# [371]	validation-rmse:5.62349
# [372]	validation-rmse:5.62344
# [373]	validation-rmse:5.62347
# [374]	validation-rmse:5.62342
# [375]	validation-rmse:5.62329
# [376]	validation-rmse:5.62318
# [377]	validation-rmse:5.62318
# [378]	validation-rmse:5.62282
# [379]	validation-rmse:5.62181
# [380]	validation-rmse:5.62165
# [381]	validation-rmse:5.62156
# [382]	validation-rmse:5.62153
# [383]	validation-rmse:5.62115
# [384]	validation-rmse:5.62107
# [385]	validation-rmse:5.62105
# [386]	validation-rmse:5.62103
# [387]	validation-rmse:5.62099
# [388]	validation-rmse:5.62072
# [389]	validation-rmse:5.62063
# [390]	validation-rmse:5.62057
# [391]	validation-rmse:5.62035
# [392]	validation-rmse:5.62026
# [393]	validation-rmse:5.62029
# [394]	validation-rmse:5.62034
# [395]	validation-rmse:5.62020
# [396]	validation-rmse:5.62017
# [397]	validation-rmse:5.62011
# [398]	validation-rmse:5.62005
# [399]	validation-rmse:5.61994
# [400]	validation-rmse:5.61981
# [401]	validation-rmse:5.61980
# [402]	validation-rmse:5.61989
# [403]	validation-rmse:5.61984
# [404]	validation-rmse:5.61970
# [405]	validation-rmse:5.61964
# [406]	validation-rmse:5.61949
# [407]	validation-rmse:5.61951
# [408]	validation-rmse:5.61944
# [409]	validation-rmse:5.61933
# [410]	validation-rmse:5.61928
# [411]	validation-rmse:5.61911
# [412]	validation-rmse:5.61916
# [413]	validation-rmse:5.61899
# [414]	validation-rmse:5.61878
# [415]	validation-rmse:5.61865
# [416]	validation-rmse:5.61849
# [417]	validation-rmse:5.61849
# [418]	validation-rmse:5.61830
# [419]	validation-rmse:5.61821
# [420]	validation-rmse:5.61826
# [421]	validation-rmse:5.61815
# [422]	validation-rmse:5.61809
# [423]	validation-rmse:5.61807
# [424]	validation-rmse:5.61804
# [425]	validation-rmse:5.61798
# [426]	validation-rmse:5.61793
# [427]	validation-rmse:5.61783
# [428]	validation-rmse:5.61769
# [429]	validation-rmse:5.61758
# [430]	validation-rmse:5.61746
# [431]	validation-rmse:5.61746
# [432]	validation-rmse:5.61737
# [433]	validation-rmse:5.61721
# [434]	validation-rmse:5.61708
# [435]	validation-rmse:5.61702
# [436]	validation-rmse:5.61691
# [437]	validation-rmse:5.61686
# [438]	validation-rmse:5.61674
# [439]	validation-rmse:5.61661
# [440]	validation-rmse:5.61643
# [441]	validation-rmse:5.61635
# [442]	validation-rmse:5.61618
# [443]	validation-rmse:5.61606
# [444]	validation-rmse:5.61601
# [445]	validation-rmse:5.61594
# [446]	validation-rmse:5.61593
# [447]	validation-rmse:5.61587
# [448]	validation-rmse:5.61579
# [449]	validation-rmse:5.61553
# [450]	validation-rmse:5.61547
# [451]	validation-rmse:5.61544
# [452]	validation-rmse:5.61535
# [453]	validation-rmse:5.61523
# [454]	validation-rmse:5.61397
# [455]	validation-rmse:5.61382
# [456]	validation-rmse:5.61393
# [457]	validation-rmse:5.61372
# [458]	validation-rmse:5.61362
# [459]	validation-rmse:5.61356
# [460]	validation-rmse:5.61347
# [461]	validation-rmse:5.61343
# [462]	validation-rmse:5.61336
# [463]	validation-rmse:5.61320
# [464]	validation-rmse:5.61324
# [465]	validation-rmse:5.61326
# [466]	validation-rmse:5.61314
# [467]	validation-rmse:5.61309
# [468]	validation-rmse:5.61307
# [469]	validation-rmse:5.61306
# [470]	validation-rmse:5.61299
# [471]	validation-rmse:5.61078
# [472]	validation-rmse:5.61030
# [473]	validation-rmse:5.61046
# [474]	validation-rmse:5.61044
# [475]	validation-rmse:5.61040
# [476]	validation-rmse:5.61022
# [477]	validation-rmse:5.61018
# [478]	validation-rmse:5.60998
# [479]	validation-rmse:5.60983
# [480]	validation-rmse:5.60969
# [481]	validation-rmse:5.60963
# [482]	validation-rmse:5.60951
# [483]	validation-rmse:5.60942
# [484]	validation-rmse:5.60924
# [485]	validation-rmse:5.60906
# [486]	validation-rmse:5.60894
# [487]	validation-rmse:5.60892
# [488]	validation-rmse:5.60877
# [489]	validation-rmse:5.60896
# [490]	validation-rmse:5.60886
# [491]	validation-rmse:5.60846
# [492]	validation-rmse:5.60844
# [493]	validation-rmse:5.60835
# [494]	validation-rmse:5.60827
# [495]	validation-rmse:5.60813
# [496]	validation-rmse:5.60801
# [497]	validation-rmse:5.60789
# [498]	validation-rmse:5.60772
# [499]	validation-rmse:5.60768
# [500]	validation-rmse:5.60759
# [501]	validation-rmse:5.60760
# [502]	validation-rmse:5.60750
# [503]	validation-rmse:5.60739
# [504]	validation-rmse:5.60729
# [505]	validation-rmse:5.60721
# [506]	validation-rmse:5.60717
# [507]	validation-rmse:5.60715
# [508]	validation-rmse:5.60699
# [509]	validation-rmse:5.60695
# [510]	validation-rmse:5.60687
# [511]	validation-rmse:5.60677
# [512]	validation-rmse:5.60674
# [513]	validation-rmse:5.60669
# [514]	validation-rmse:5.60665
# [515]	validation-rmse:5.60660
# [516]	validation-rmse:5.60665
# [517]	validation-rmse:5.60664
# [518]	validation-rmse:5.60656
# [519]	validation-rmse:5.60655
# [520]	validation-rmse:5.60646
# [521]	validation-rmse:5.60658
# [522]	validation-rmse:5.60660
# [523]	validation-rmse:5.60671
# [524]	validation-rmse:5.60664
# [525]	validation-rmse:5.60662
# [526]	validation-rmse:5.60649
# [527]	validation-rmse:5.60648
# [528]	validation-rmse:5.60651
# [529]	validation-rmse:5.60643
# [530]	validation-rmse:5.60629
# [531]	validation-rmse:5.60625
# [532]	validation-rmse:5.60619
# [533]	validation-rmse:5.60602
# [534]	validation-rmse:5.60592
# [535]	validation-rmse:5.60593
# [536]	validation-rmse:5.60589
# [537]	validation-rmse:5.60584
# [538]	validation-rmse:5.60578
# [539]	validation-rmse:5.60572
# [540]	validation-rmse:5.60572
# [541]	validation-rmse:5.60551
# [542]	validation-rmse:5.60543
# [543]	validation-rmse:5.60531
# [544]	validation-rmse:5.60534
# [545]	validation-rmse:5.60531
# [546]	validation-rmse:5.60517
# [547]	validation-rmse:5.60517
# [548]	validation-rmse:5.60493
# [549]	validation-rmse:5.60495
# [550]	validation-rmse:5.60481
# [551]	validation-rmse:5.60479
# [552]	validation-rmse:5.60470
# [553]	validation-rmse:5.60448
# [554]	validation-rmse:5.60441
# [555]	validation-rmse:5.60431
# [556]	validation-rmse:5.60430
# [557]	validation-rmse:5.60418
# [558]	validation-rmse:5.60421
# [559]	validation-rmse:5.60415
# [560]	validation-rmse:5.60412
# [561]	validation-rmse:5.60399
# [562]	validation-rmse:5.60397
# [563]	validation-rmse:5.60391
# [564]	validation-rmse:5.60403
# [565]	validation-rmse:5.60399
# [566]	validation-rmse:5.60387
# [567]	validation-rmse:5.60367
# [568]	validation-rmse:5.60362
# [569]	validation-rmse:5.60353
# [570]	validation-rmse:5.60230
# [571]	validation-rmse:5.60235
# [572]	validation-rmse:5.60240
# [573]	validation-rmse:5.60224
# [574]	validation-rmse:5.60217
# [575]	validation-rmse:5.60218
# [576]	validation-rmse:5.60219
# [577]	validation-rmse:5.60205
# [578]	validation-rmse:5.60191
# [579]	validation-rmse:5.60192
# [580]	validation-rmse:5.60172
# [581]	validation-rmse:5.60172
# [582]	validation-rmse:5.60163
# [583]	validation-rmse:5.60129
# [584]	validation-rmse:5.60124
# [585]	validation-rmse:5.60055
# [586]	validation-rmse:5.60085
# [587]	validation-rmse:5.60086
# [588]	validation-rmse:5.60087
# [589]	validation-rmse:5.60077
# [590]	validation-rmse:5.60050
# [591]	validation-rmse:5.60043
# [592]	validation-rmse:5.60041
# [593]	validation-rmse:5.60031
# [594]	validation-rmse:5.60009
# [595]	validation-rmse:5.59972
# [596]	validation-rmse:5.59963
# [597]	validation-rmse:5.59955
# [598]	validation-rmse:5.59953
# [599]	validation-rmse:5.59952
# [600]	validation-rmse:5.59942
# [601]	validation-rmse:5.59930
# [602]	validation-rmse:5.59917
# [603]	validation-rmse:5.59908
# [604]	validation-rmse:5.59908
# [605]	validation-rmse:5.59912
# [606]	validation-rmse:5.59912
# [607]	validation-rmse:5.59914
# [608]	validation-rmse:5.59907
# [609]	validation-rmse:5.59904
# [610]	validation-rmse:5.59886
# [611]	validation-rmse:5.59881
# [612]	validation-rmse:5.59876
# [613]	validation-rmse:5.59873
# [614]	validation-rmse:5.59873
# [615]	validation-rmse:5.59861
# [616]	validation-rmse:5.59845
# [617]	validation-rmse:5.59840
# [618]	validation-rmse:5.59832
# [619]	validation-rmse:5.59826
# [620]	validation-rmse:5.59823
# [621]	validation-rmse:5.59829
# [622]	validation-rmse:5.59823
# [623]	validation-rmse:5.59818
# [624]	validation-rmse:5.59812
# [625]	validation-rmse:5.59791
# [626]	validation-rmse:5.59767
# [627]	validation-rmse:5.59753
# [628]	validation-rmse:5.59748
# [629]	validation-rmse:5.59735
# [630]	validation-rmse:5.59736
# [631]	validation-rmse:5.59722
# [632]	validation-rmse:5.59717
# [633]	validation-rmse:5.59714
# [634]	validation-rmse:5.59705
# [635]	validation-rmse:5.59700
# [636]	validation-rmse:5.59691
# [637]	validation-rmse:5.59683
# [638]	validation-rmse:5.59678
# [639]	validation-rmse:5.59684
# [640]	validation-rmse:5.59683
# [641]	validation-rmse:5.59671
# [642]	validation-rmse:5.59665
# [643]	validation-rmse:5.59663
# [644]	validation-rmse:5.59667
# [645]	validation-rmse:5.59642
# [646]	validation-rmse:5.59637
# [647]	validation-rmse:5.59633
# [648]	validation-rmse:5.59630
# [649]	validation-rmse:5.59647
# [650]	validation-rmse:5.59647
# [651]	validation-rmse:5.59651
# [652]	validation-rmse:5.59650
# [653]	validation-rmse:5.59639
# [654]	validation-rmse:5.59636
# [655]	validation-rmse:5.59624
# [656]	validation-rmse:5.59620
# [657]	validation-rmse:5.59611
# [658]	validation-rmse:5.59611
# [659]	validation-rmse:5.59582
# [660]	validation-rmse:5.59579
# [661]	validation-rmse:5.59579
# [662]	validation-rmse:5.59584
# [663]	validation-rmse:5.59579
# [664]	validation-rmse:5.59579
# [665]	validation-rmse:5.59571
# [666]	validation-rmse:5.59561
# [667]	validation-rmse:5.59556
# [668]	validation-rmse:5.59545
# [669]	validation-rmse:5.59542
# [670]	validation-rmse:5.59554
# [671]	validation-rmse:5.59558
# [672]	validation-rmse:5.59552
# [673]	validation-rmse:5.59543
# [674]	validation-rmse:5.59540
# [675]	validation-rmse:5.59518
# [676]	validation-rmse:5.59501
# [677]	validation-rmse:5.59486
# [678]	validation-rmse:5.59493
# [679]	validation-rmse:5.59485
# [680]	validation-rmse:5.59488
# [681]	validation-rmse:5.59491
# [682]	validation-rmse:5.59490
# [683]	validation-rmse:5.59503
# [684]	validation-rmse:5.59500
# [685]	validation-rmse:5.59503
# [686]	validation-rmse:5.59477
# [687]	validation-rmse:5.59473
# [688]	validation-rmse:5.59474
# [689]	validation-rmse:5.59473
# [690]	validation-rmse:5.59461
# [691]	validation-rmse:5.59457
# [692]	validation-rmse:5.59450
# [693]	validation-rmse:5.59435
# [694]	validation-rmse:5.59436
# [695]	validation-rmse:5.59424
# [696]	validation-rmse:5.59423
# [697]	validation-rmse:5.59418
# [698]	validation-rmse:5.59418
# [699]	validation-rmse:5.59409
# [700]	validation-rmse:5.59406
# [701]	validation-rmse:5.59400
# [702]	validation-rmse:5.59400
# [703]	validation-rmse:5.59360
# [704]	validation-rmse:5.59365
# [705]	validation-rmse:5.59358
# [706]	validation-rmse:5.59343
# [707]	validation-rmse:5.59339
# [708]	validation-rmse:5.59345
# [709]	validation-rmse:5.59336
# [710]	validation-rmse:5.59332
# [711]	validation-rmse:5.59327
# [712]	validation-rmse:5.59319
# [713]	validation-rmse:5.59318
# [714]	validation-rmse:5.59314
# [715]	validation-rmse:5.59309
# [716]	validation-rmse:5.59275
# [717]	validation-rmse:5.59265
# [718]	validation-rmse:5.59267
# [719]	validation-rmse:5.59263
# [720]	validation-rmse:5.59328
# [721]	validation-rmse:5.59319
# [722]	validation-rmse:5.59317
# [723]	validation-rmse:5.59303
# [724]	validation-rmse:5.59400
# [725]	validation-rmse:5.59420
# [726]	validation-rmse:5.59431
# [727]	validation-rmse:5.59436
# [728]	validation-rmse:5.59416
# [729]	validation-rmse:5.59403
# [730]	validation-rmse:5.59397
# [731]	validation-rmse:5.59382
# [732]	validation-rmse:5.59374
# [733]	validation-rmse:5.59378
# [734]	validation-rmse:5.59377
# [735]	validation-rmse:5.59374
# [736]	validation-rmse:5.59371
# [737]	validation-rmse:5.59362
# [738]	validation-rmse:5.59359
# [739]	validation-rmse:5.59353
# [740]	validation-rmse:5.59353
# [741]	validation-rmse:5.59357
# [742]	validation-rmse:5.59350
# [743]	validation-rmse:5.59344
# [744]	validation-rmse:5.59346
# [745]	validation-rmse:5.59342
# [746]	validation-rmse:5.59342
# [747]	validation-rmse:5.59332
# [748]	validation-rmse:5.59342
# [749]	validation-rmse:5.59348
# [750]	validation-rmse:5.59325
# [751]	validation-rmse:5.59304
# [752]	validation-rmse:5.59297
# [753]	validation-rmse:5.59287
# [754]	validation-rmse:5.59277
# [755]	validation-rmse:5.59270
# [756]	validation-rmse:5.59272
# [757]	validation-rmse:5.59272
# [758]	validation-rmse:5.59271
# [759]	validation-rmse:5.59253
# [760]	validation-rmse:5.59263
# [761]	validation-rmse:5.59261
# [762]	validation-rmse:5.59253
# [763]	validation-rmse:5.59253
# [764]	validation-rmse:5.59255
# [765]	validation-rmse:5.59252
# [766]	validation-rmse:5.59243
# [767]	validation-rmse:5.59239
# [768]	validation-rmse:5.59236
# [769]	validation-rmse:5.59232
# [770]	validation-rmse:5.59221
# [771]	validation-rmse:5.59222
# [772]	validation-rmse:5.59224
# [773]	validation-rmse:5.59223
# [774]	validation-rmse:5.59212
# [775]	validation-rmse:5.59201
# [776]	validation-rmse:5.59198
# [777]	validation-rmse:5.59188
# [778]	validation-rmse:5.59215
# [779]	validation-rmse:5.59124
# [780]	validation-rmse:5.59057
# [781]	validation-rmse:5.59053
# [782]	validation-rmse:5.59049
# [783]	validation-rmse:5.59023
# [784]	validation-rmse:5.59015
# [785]	validation-rmse:5.59008
# [786]	validation-rmse:5.59017
# [787]	validation-rmse:5.59012
# [788]	validation-rmse:5.59008
# [789]	validation-rmse:5.59005
# [790]	validation-rmse:5.59005
# [791]	validation-rmse:5.58989
# [792]	validation-rmse:5.58986
# [793]	validation-rmse:5.58984
# [794]	validation-rmse:5.58987
# [795]	validation-rmse:5.59000
# [796]	validation-rmse:5.58996
# [797]	validation-rmse:5.58986
# [798]	validation-rmse:5.58985
# [799]	validation-rmse:5.59022
# [800]	validation-rmse:5.59013
# [801]	validation-rmse:5.59006
# [802]	validation-rmse:5.58990
# [803]	validation-rmse:5.58983
# [804]	validation-rmse:5.58989
# [805]	validation-rmse:5.58983
# [806]	validation-rmse:5.58981
# [807]	validation-rmse:5.58976
# [808]	validation-rmse:5.58964
# [809]	validation-rmse:5.58963
# [810]	validation-rmse:5.58966
# [811]	validation-rmse:5.58959
# [812]	validation-rmse:5.58949
# [813]	validation-rmse:5.58942
# [814]	validation-rmse:5.58945
# [815]	validation-rmse:5.58945
# [816]	validation-rmse:5.58946
# [817]	validation-rmse:5.58947
# [818]	validation-rmse:5.58963
# [819]	validation-rmse:5.58971
# [820]	validation-rmse:5.58967
# [821]	validation-rmse:5.58970
# [822]	validation-rmse:5.58966
# [823]	validation-rmse:5.58956
# [824]	validation-rmse:5.58971
# [825]	validation-rmse:5.58972
# [826]	validation-rmse:5.58972
# [827]	validation-rmse:5.58968
# [828]	validation-rmse:5.58968
# [829]	validation-rmse:5.58963
# [830]	validation-rmse:5.58958
# [831]	validation-rmse:5.58947
# [832]	validation-rmse:5.58924
# [833]	validation-rmse:5.58924
# [834]	validation-rmse:5.58912
# [835]	validation-rmse:5.58911
# [836]	validation-rmse:5.58905
# [837]	validation-rmse:5.58896
# [838]	validation-rmse:5.58889
# [839]	validation-rmse:5.58893
# [840]	validation-rmse:5.58897
# [841]	validation-rmse:5.58896
# [842]	validation-rmse:5.58897
# [843]	validation-rmse:5.58891
# [844]	validation-rmse:5.58883
# [845]	validation-rmse:5.58878
# [846]	validation-rmse:5.58881
# [847]	validation-rmse:5.58876
# [848]	validation-rmse:5.58879
# [849]	validation-rmse:5.58895
# [850]	validation-rmse:5.58886
# [851]	validation-rmse:5.58885
# [852]	validation-rmse:5.58873
# [853]	validation-rmse:5.58875
# [854]	validation-rmse:5.58875
# [855]	validation-rmse:5.58869
# [856]	validation-rmse:5.58849
# [857]	validation-rmse:5.58842
# [858]	validation-rmse:5.58840
# [859]	validation-rmse:5.58817
# [860]	validation-rmse:5.58812
# [861]	validation-rmse:5.58807
# [862]	validation-rmse:5.58797
# [863]	validation-rmse:5.58804
# [864]	validation-rmse:5.58802
# [865]	validation-rmse:5.58801
# [866]	validation-rmse:5.58803
# [867]	validation-rmse:5.58798
# [868]	validation-rmse:5.58792
# [869]	validation-rmse:5.58792
# [870]	validation-rmse:5.58790
# [871]	validation-rmse:5.58786
# [872]	validation-rmse:5.58777
# [873]	validation-rmse:5.58769
# [874]	validation-rmse:5.58764
# [875]	validation-rmse:5.58760
# [876]	validation-rmse:5.58756
# [877]	validation-rmse:5.58756
# [878]	validation-rmse:5.58753
# [879]	validation-rmse:5.58752
# [880]	validation-rmse:5.58749
# [881]	validation-rmse:5.58709
# [882]	validation-rmse:5.58704
# [883]	validation-rmse:5.58698
# [884]	validation-rmse:5.58702
# [885]	validation-rmse:5.58702
# [886]	validation-rmse:5.58695
# [887]	validation-rmse:5.58696
# [888]	validation-rmse:5.58688
# [889]	validation-rmse:5.58681
# [890]	validation-rmse:5.58670
# [891]	validation-rmse:5.58667
# [892]	validation-rmse:5.58662
# [893]	validation-rmse:5.58683
# [894]	validation-rmse:5.58805
# [895]	validation-rmse:5.58814
# [896]	validation-rmse:5.58834
# [897]	validation-rmse:5.58838
# [898]	validation-rmse:5.58571
# [899]	validation-rmse:5.58570
# [900]	validation-rmse:5.58562
# [901]	validation-rmse:5.58559
# [902]	validation-rmse:5.58561
# [903]	validation-rmse:5.58561
# [904]	validation-rmse:5.58565
# [905]	validation-rmse:5.58564
# [906]	validation-rmse:5.58571
# [907]	validation-rmse:5.58570
# [908]	validation-rmse:5.58558
# [909]	validation-rmse:5.58541
# [910]	validation-rmse:5.58538
# [911]	validation-rmse:5.58523
# [912]	validation-rmse:5.58521
# [913]	validation-rmse:5.58521
# [914]	validation-rmse:5.58574
# [915]	validation-rmse:5.58578
# [916]	validation-rmse:5.58577
# [917]	validation-rmse:5.58582
# [918]	validation-rmse:5.58581
# [919]	validation-rmse:5.58590
# [920]	validation-rmse:5.58589
# [921]	validation-rmse:5.58588
# [922]	validation-rmse:5.58581
# [923]	validation-rmse:5.58582
# [924]	validation-rmse:5.58591
# [925]	validation-rmse:5.58589
# [926]	validation-rmse:5.58586
# [927]	validation-rmse:5.58582
# [928]	validation-rmse:5.58581
# [929]	validation-rmse:5.58582
# [930]	validation-rmse:5.58583
# [931]	validation-rmse:5.58567
# [932]	validation-rmse:5.58589
# [933]	validation-rmse:5.58599
# [934]	validation-rmse:5.58500
# [935]	validation-rmse:5.58493
# [936]	validation-rmse:5.58482
# [937]	validation-rmse:5.58483
# [938]	validation-rmse:5.58494
# [939]	validation-rmse:5.58492
# [940]	validation-rmse:5.58488
# [941]	validation-rmse:5.58489
# [942]	validation-rmse:5.58486
# [943]	validation-rmse:5.58465
# [944]	validation-rmse:5.58472
# [945]	validation-rmse:5.58470
# [946]	validation-rmse:5.58459
# [947]	validation-rmse:5.58464
# [948]	validation-rmse:5.58459
# [949]	validation-rmse:5.58454
# [950]	validation-rmse:5.58456
# [951]	validation-rmse:5.58445
# [952]	validation-rmse:5.58436
# [953]	validation-rmse:5.58438
# [954]	validation-rmse:5.58428
# [955]	validation-rmse:5.58429
# [956]	validation-rmse:5.58425
# [957]	validation-rmse:5.58425
# [958]	validation-rmse:5.58421
# [959]	validation-rmse:5.58422
# [960]	validation-rmse:5.58417
# [961]	validation-rmse:5.58420
# [962]	validation-rmse:5.58417
# [963]	validation-rmse:5.58409
# [964]	validation-rmse:5.58400
# [965]	validation-rmse:5.58400
# [966]	validation-rmse:5.58399
# [967]	validation-rmse:5.58400
# [968]	validation-rmse:5.58396
# [969]	validation-rmse:5.58396
# [970]	validation-rmse:5.58400
# [971]	validation-rmse:5.58398
# [972]	validation-rmse:5.58396
# [973]	validation-rmse:5.58411
# [974]	validation-rmse:5.58405
# [975]	validation-rmse:5.58406
# [976]	validation-rmse:5.58407
# [977]	validation-rmse:5.58407
# [978]	validation-rmse:5.58405
# [979]	validation-rmse:5.58401
# [980]	validation-rmse:5.58396
# [981]	validation-rmse:5.58390
# [982]	validation-rmse:5.58373
# [983]	validation-rmse:5.58346
# [984]	validation-rmse:5.58345
# [985]	validation-rmse:5.58339
# [986]	validation-rmse:5.58335
# [987]	validation-rmse:5.58346
# [988]	validation-rmse:5.58134
# [989]	validation-rmse:5.58121
# [990]	validation-rmse:5.58088
# [991]	validation-rmse:5.58089
# [992]	validation-rmse:5.58099
# [993]	validation-rmse:5.58091
# [994]	validation-rmse:5.58094
# [995]	validation-rmse:5.58082
# [996]	validation-rmse:5.58078
# [997]	validation-rmse:5.58070
# [998]	validation-rmse:5.58071
# [999]	validation-rmse:5.58070
